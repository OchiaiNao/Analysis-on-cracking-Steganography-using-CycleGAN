# %%
import torch
import os
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from torchvision.datasets import ImageFolder
from itertools import cycle
from PIL import Image
from torchvision.utils import save_image
import numpy as np
import torchvision.utils as vutils
import pywt
import cv2

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1),
            nn.InstanceNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1),
            nn.InstanceNorm2d(in_channels),
        )

    def forward(self, x):
        return x + self.block(x)

class Generator(nn.Module):
    def __init__(self, num_res_blocks=6):
        super(Generator, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.InstanceNorm2d(256),
            nn.ReLU(inplace=True),
        )
        
         # Create a list of residual blocks with the specified number of blocks
        res_blocks = [ResidualBlock(256) for _ in range(num_res_blocks)]
        # Convert the list of residual blocks to a sequential model
        self.residual_blocks = nn.Sequential(*res_blocks)

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 3, kernel_size=3, stride=1, padding=1),
            nn.Tanh(),
        )

    def forward(self, x):
        # Encoder-decoder forward pass
        x = self.encoder(x)
        x = self.residual_blocks(x)
        x = self.decoder(x)
        return x

# %%
# PatchGAN Discriminator class
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.InstanceNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.InstanceNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.InstanceNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(512, 1, kernel_size=3, stride=1, padding=1),
        )
    # Implement the forward pass by passing the input through the layers and reshaping the output
    def forward(self, x):
        return self.layers(x).view(x.size(0), -1)

# %%
def dwt_embed(cover_image, secret_image):
    device = cover_image.device

    # Convert the cover and secret images from PyTorch tensors to NumPy arrays
    cover_image_np = tensor_to_np(cover_image.cpu())
    secret_image_np = tensor_to_np(secret_image.cpu())

    # Compute the DWT coefficients for the cover and secret images using the Haar wavelet
    cover_coeffs = pywt.dwt2(cover_image_np, 'haar')
    secret_coeffs = pywt.dwt2(secret_image_np, 'haar')

    # Keep only the most significant bit of the secret coefficients
    msb_mask = 0b10000000 
    secret_coeffs_msb = tuple([(np.uint8(coeff) & msb_mask) for coeff in secret_coeffs])
    
    
    # Encoding here:
    # Combine the coefficients of the cover and secret images
    stego_coeffs = (cover_coeffs[0] + secret_coeffs_msb[0], cover_coeffs[1])

    # Compute the inverse DWT to obtain the stego image
    stego_image_np = pywt.idwt2(stego_coeffs, 'haar').clip(0, 255).astype(np.uint8)

    # Return tensors
    return np_to_tensor(stego_image_np, device)



def dwt_extract(stego_image, cover_image):
    device = stego_image.device
    
    # Convert the stego and cover images from PyTorch tensors to NumPy arrays
    stego_image_np = tensor_to_np(stego_image.cpu())
    cover_image_np = tensor_to_np(cover_image.cpu())
    
    # Compute the DWT coefficients for the stego and cover images using the Haar wavelet
    stego_coeffs = pywt.dwt2(stego_image_np, 'haar')
    cover_coeffs = pywt.dwt2(cover_image_np, 'haar')
    
    msb_mask = 0b10000000
    # Decoding here:
    # Calculate the hidden image coefficients by subtracting the cover coefficients from the stego coefficients
    secret_coeffs_msb = tuple([(np.uint8(coeff) & msb_mask) for coeff in (stego_coeffs[0] - cover_coeffs[0])])
    
    
    # Compute the inverse DWT to obtain the hidden image
    secret_coeffs = (secret_coeffs_msb, cover_coeffs[1])
    secret_image_np = pywt.idwt2(secret_coeffs, 'haar').clip(0, 255).astype(np.uint8)
    
    # Return tensors
    return np_to_tensor(secret_image_np, device)

def tensor_to_np(tensor):
    return tensor.detach().cpu().numpy()

def np_to_tensor(array, device):
    return torch.tensor(array, device=device, dtype=torch.float32)

# %%
def train(generator_H2S, generator_S2H,
          discriminator_H, discriminator_S,
          cover_loader, stego_loader, hidden_loader,
          val_cover_loader, val_stego_loader, val_hidden_loader, device, 
          optimizer_G,
          optimizer_H, optimizer_S, 
          num_epochs, flag):
    
    """
    Train function for the cycle_GAN model.

    Parameters:
    - generator_H2S (nn.Module): The generator model that transforms hidden images to stego images.
    - generator_S2H (nn.Module): The generator model that transforms stego images to hidden images.
    - discriminator_H (nn.Module): The discriminator model that discriminates between real and fake hidden images.
    - discriminator_S (nn.Module): The discriminator model that discriminates between real and fake stego images.
    - cover_loader (DataLoader): DataLoader for cover images.
    - stego_loader (DataLoader): DataLoader for stego images.
    - hidden_loader (DataLoader): DataLoader for hidden images.
    - val_cover_loader (DataLoader): DataLoader for validation cover images.
    - val_stego_loader (DataLoader): DataLoader for validation stego images.
    - val_hidden_loader (DataLoader): DataLoader for validation hidden images.
    - device (torch.device): Device to perform computations on (CPU or GPU).
    - optimizer_G (torch.optim.Optimizer): Optimizer for both generator models (generator_H2S and generator_S2H).
    - optimizer_H (torch.optim.Optimizer): Optimizer for the discriminator_H model.
    - optimizer_S (torch.optim.Optimizer): Optimizer for the discriminator_S model.
    - num_epochs (int): The number of epochs to train the model.
    - flag (int): Flag to check where the save should start (flag+epoch).
    """
    
    for epoch in range(num_epochs):
        for cover, stego, hidden in zip(cover_loader, stego_loader, hidden_loader):
            
            # Unpack images and labels from the data loaders
            cover_img, _ = cover
            stego_img, _ = stego
            hidden_img, _ = hidden
            
            # Move images to device
            cover_img = cover_img.to(device)
            stego_img = stego_img.to(device)
            hidden_img = hidden_img.to(device)

            # --------------------
            # Train the generators
            # --------------------
            
            """
            # Identity loss
            same_hidden = generator_S2H(hidden_img)
            loss_identity_H = criterion_cycle(same_hidden, hidden_img) * 5.0
            
            same_stego = generator_H2S(stego_img)
            loss_identity_S = criterion_cycle(same_stego, stego_img) * 5.0
            """

            # GAN loss
            fake_hidden = generator_S2H(stego_img)
            pred_fake_hidden = discriminator_H(fake_hidden)
            loss_gan_S2H = criterion_gan(pred_fake_hidden, torch.ones_like(pred_fake_hidden))

            fake_stego = generator_H2S(hidden_img)
            pred_fake_stego = discriminator_S(fake_stego)
            loss_gan_H2S = criterion_gan(pred_fake_stego, torch.ones_like(pred_fake_stego))

            # Cycle loss
            
            # Use dwt_embed to recover stego image
            recovered_stego = generator_H2S(fake_hidden)
            dwt_recovered_stego = dwt_embed(cover_img, fake_hidden)
            loss_cycle_S = criterion_cycle(recovered_stego, dwt_recovered_stego) * 10.0
            
            # Use dwt_extract to recover hidden image
            recovered_hidden = generator_S2H(fake_stego)
            dwt_recovered_hidden = dwt_extract(fake_stego, cover_img)
            loss_cycle_H = criterion_cycle(recovered_hidden, dwt_recovered_hidden) * 10.0

            # Total generator loss
            total_g_loss = loss_gan_S2H + loss_gan_H2S + loss_cycle_S + loss_cycle_H
            total_g_loss.backward()
            
            optimizer_G.step()
            
            # ------------------------
            # Train the discriminators
            # ------------------------
            
            optimizer_H.zero_grad()
            optimizer_S.zero_grad()
            
            # Discriminator S
            
            # Real loss
            pred_real_stego = discriminator_S(stego_img)
            loss_d_real_stego = criterion_gan(pred_real_stego, torch.ones_like(pred_real_stego))

            # Fake loss
            fake_stego.detach_()
            pred_fake_stego = discriminator_S(fake_stego)
            loss_d_fake_stego = criterion_gan(pred_fake_stego, torch.zeros_like(pred_fake_stego))

            # Total Discriminator S loss
            total_d_s_loss = (loss_d_real_stego + loss_d_fake_stego) * 0.5
            total_d_s_loss.backward()

            optimizer_S.step()
            
            # Discriminator H
            
            # Real loss
            pred_real_hidden = discriminator_H(hidden_img)
            loss_d_real_hidden = criterion_gan(pred_real_hidden, torch.ones_like(pred_real_hidden))

            # Fake loss
            fake_hidden.detach_()
            pred_fake_hidden = discriminator_H(fake_hidden)
            loss_d_fake_hidden = criterion_gan(pred_fake_hidden, torch.zeros_like(pred_fake_hidden))

            # Total Discriminator H loss
            total_d_h_loss = (loss_d_real_hidden + loss_d_fake_hidden) * 0.5
            total_d_h_loss.backward()
            
            optimizer_H.step()


        print(f"Epoch [{epoch+1}/{num_epochs}] | Generator Loss: {total_g_loss.item():.4f} | Discriminator S Loss: {total_d_s_loss.item():.4f} | Discriminator H Loss: {total_d_h_loss.item():.4f}")

        # Save the model checkpoints every 50 epochs
        if (epoch + 1) % 50 == 0:
            torch.save(generator_H2S.state_dict(), f'./model_params/DWT/H2S/generator_H2S_epoch_{flag+epoch+1}.pth')
            torch.save(generator_S2H.state_dict(), f'./model_params/DWT/S2H/generator_S2H_epoch_{flag+epoch+1}.pth')
            torch.save(discriminator_H.state_dict(), f'./model_params/DWT/DH/discriminator_H_epoch_{flag+epoch+1}.pth')
            torch.save(discriminator_S.state_dict(), f'./model_params/DWT/DS/discriminator_S_epoch_{flag+epoch+1}.pth')
            torch.save(optimizer_G.state_dict(), f'./model_params/DWT/optimizer/G/optimizer_G_{flag+epoch+1}.pth')
            torch.save(optimizer_H.state_dict(), f'./model_params/DWT/optimizer/H/optimizer_H_{flag+epoch+1}.pth')
            torch.save(optimizer_S.state_dict(), f'./model_params/DWT/optimizer/S/optimizer_S_{flag+epoch+1}.pth')
        # Valid the model every 10 epochs
        if (epoch + 1) % 10 == 0:
            generator_H2S.eval()
            generator_S2H.eval()
            discriminator_H.eval()
            discriminator_S.eval()
            
            with torch.no_grad():
                for val_cover, val_stego, val_hidden in zip(val_cover_loader, val_stego_loader, val_hidden_loader):
                    val_cover_img, _ = val_cover
                    val_stego_img, _ = val_stego
                    val_hidden_img, _ = val_hidden

                    val_cover_img = val_cover_img.to(device)
                    val_stego_img = val_stego_img.to(device)
                    val_hidden_img = val_hidden_img.to(device)

                    fake_hidden = generator_S2H(val_stego_img)
                    fake_stego = generator_H2S(val_hidden_img)
                    recovered_hidden = generator_S2H(fake_stego)
                    recovered_stego = generator_H2S(fake_hidden)

                    val_g_loss = criterion_cycle(recovered_hidden, val_hidden_img) + criterion_cycle(recovered_stego, val_stego_img)
                    val_d_h_loss = criterion_gan(discriminator_H(val_hidden_img), torch.ones_like(discriminator_H(val_hidden_img))) + criterion_gan(discriminator_H(fake_hidden.detach()), torch.zeros_like(discriminator_H(fake_hidden.detach())))
                    val_d_s_loss = criterion_gan(discriminator_S(val_stego_img), torch.ones_like(discriminator_S(val_stego_img))) + criterion_gan(discriminator_S(fake_stego.detach()), torch.zeros_like(discriminator_S(fake_stego.detach())))
                    
            generator_H2S.train()
            generator_S2H.train()
            discriminator_H.train()
            discriminator_S.train()
            print(f"Validation | Generator Loss: {val_g_loss.item():.4f} | Discriminator S Loss: {val_d_s_loss.item():.4f} | Discriminator H Loss: {val_d_h_loss.item():.4f}")

# %%
# Set device
device = torch.device('cuda')

# Load the datasets
transform = transforms.Compose([
    transforms.Resize((96, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# Train set
dataset_cover =ImageFolder('./train/cover', transform=transform)
dataset_stego = ImageFolder('./train/stego', transform=transform)
dataset_hidden = ImageFolder('./train/DWT_hidden', transform=transform)

cover_loader = DataLoader(dataset_cover, batch_size=1)
stego_loader = DataLoader(dataset_stego, batch_size=1)
hidden_loader = DataLoader(dataset_hidden, batch_size=1)

# Val set
dataset_cover_val = ImageFolder('./valid/cover', transform=transform)
dataset_stego_val = ImageFolder('./valid/stego', transform=transform)
dataset_hidden_val = ImageFolder('./valid/DWT_hidden', transform=transform)

val_cover_loader = DataLoader(dataset_cover_val, batch_size=1)
val_stego_loader = DataLoader(dataset_stego_val, batch_size=1)
val_hidden_loader = DataLoader(dataset_hidden_val, batch_size=1)

# Test set
dataset_cover_test = ImageFolder('./test/cover', transform=transform)
dataset_stego_test = ImageFolder('./test/stego', transform=transform)
dataset_hidden_test = ImageFolder('./test/DWT_hidden', transform=transform)

test_cover_loader = DataLoader(dataset_cover_test, batch_size=1)
test_stego_loader = DataLoader(dataset_stego_test, batch_size=1)
test_hidden_loader = DataLoader(dataset_hidden_test, batch_size=1)

# %%
# Instantiate the generators and discriminators
generator_H2S = Generator()
generator_S2H = Generator()

discriminator_H = Discriminator()
discriminator_S = Discriminator()


# Set device
device = torch.device("cuda")

generator_H2S.to(device)
generator_S2H.to(device)

discriminator_H.to(device)
discriminator_S.to(device)


# Define the optimizers
optimizer_G = optim.Adam(list(generator_H2S.parameters()) + list(generator_S2H.parameters()), lr=0.001, betas=(0.5, 0.999))

optimizer_H = optim.Adam(discriminator_H.parameters(), lr=0.0001, betas=(0.5, 0.999))
optimizer_S = optim.Adam(discriminator_S.parameters(), lr=0.0001, betas=(0.5, 0.999))


# Define the loss functions
criterion_gan = torch.nn.MSELoss()
criterion_cycle = torch.nn.L1Loss()

# %%
train(generator_H2S, generator_S2H, discriminator_H, discriminator_S,
      cover_loader, stego_loader, hidden_loader, val_cover_loader, val_stego_loader, val_hidden_loader, device, optimizer_G, optimizer_H, optimizer_S, num_epochs=500, flag=0)
# Out:
# Epoch [1/500] | Generator Loss: 97.5961 | Discriminator S Loss: 0.0175 | Discriminator H Loss: 0.0119
# Epoch [2/500] | Generator Loss: 69.4685 | Discriminator S Loss: 0.0070 | Discriminator H Loss: 0.0042
# Epoch [3/500] | Generator Loss: 48.1921 | Discriminator S Loss: 0.0057 | Discriminator H Loss: 0.0026
# Epoch [4/500] | Generator Loss: 62.7466 | Discriminator S Loss: 0.0042 | Discriminator H Loss: 0.0015
# Epoch [5/500] | Generator Loss: 65.3141 | Discriminator S Loss: 0.0042 | Discriminator H Loss: 0.0022
# Epoch [6/500] | Generator Loss: 74.8980 | Discriminator S Loss: 0.0022 | Discriminator H Loss: 0.0013
# Epoch [7/500] | Generator Loss: 75.1669 | Discriminator S Loss: 0.0016 | Discriminator H Loss: 0.0019
# Epoch [8/500] | Generator Loss: 74.7388 | Discriminator S Loss: 0.0022 | Discriminator H Loss: 0.0015
# Epoch [9/500] | Generator Loss: 68.3367 | Discriminator S Loss: 0.0015 | Discriminator H Loss: 0.0012
# Epoch [10/500] | Generator Loss: 46.0432 | Discriminator S Loss: 0.0020 | Discriminator H Loss: 0.0008
# Validation | Generator Loss: 1.8652 | Discriminator S Loss: 0.0101 | Discriminator H Loss: 0.0029
# Epoch [11/500] | Generator Loss: 48.3613 | Discriminator S Loss: 0.0035 | Discriminator H Loss: 0.0003
# Epoch [12/500] | Generator Loss: 48.1963 | Discriminator S Loss: 0.0057 | Discriminator H Loss: 0.0011
# Epoch [13/500] | Generator Loss: 47.7711 | Discriminator S Loss: 0.0049 | Discriminator H Loss: 0.0016
# Epoch [14/500] | Generator Loss: 46.2614 | Discriminator S Loss: 0.0029 | Discriminator H Loss: 0.0008
# Epoch [15/500] | Generator Loss: 50.1808 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0003
# Epoch [16/500] | Generator Loss: 54.2862 | Discriminator S Loss: 0.0009 | Discriminator H Loss: 0.0052
# Epoch [17/500] | Generator Loss: 51.9610 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0010
# Epoch [18/500] | Generator Loss: 45.4368 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0023
# Epoch [19/500] | Generator Loss: 42.9769 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0008
# Epoch [20/500] | Generator Loss: 50.4685 | Discriminator S Loss: 0.0014 | Discriminator H Loss: 0.0022
# Validation | Generator Loss: 1.8848 | Discriminator S Loss: 0.0037 | Discriminator H Loss: 0.0044
# Epoch [21/500] | Generator Loss: 54.4785 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0006
# Epoch [22/500] | Generator Loss: 56.9374 | Discriminator S Loss: 0.0022 | Discriminator H Loss: 0.0035
# Epoch [23/500] | Generator Loss: 53.5857 | Discriminator S Loss: 0.0026 | Discriminator H Loss: 0.0011
# Epoch [24/500] | Generator Loss: 46.8171 | Discriminator S Loss: 0.0018 | Discriminator H Loss: 0.0027
# Epoch [25/500] | Generator Loss: 46.3447 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0006
# Epoch [26/500] | Generator Loss: 44.5947 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0030
# Epoch [27/500] | Generator Loss: 49.0111 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0008
# Epoch [28/500] | Generator Loss: 56.0858 | Discriminator S Loss: 0.0014 | Discriminator H Loss: 0.0004
# Epoch [29/500] | Generator Loss: 50.9893 | Discriminator S Loss: 0.0030 | Discriminator H Loss: 0.0018
# Epoch [30/500] | Generator Loss: 39.2564 | Discriminator S Loss: 0.0026 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 1.8922 | Discriminator S Loss: 0.0026 | Discriminator H Loss: 0.0009
# Epoch [31/500] | Generator Loss: 35.3917 | Discriminator S Loss: 0.0019 | Discriminator H Loss: 0.0002
# Epoch [32/500] | Generator Loss: 50.7638 | Discriminator S Loss: 0.0016 | Discriminator H Loss: 0.0008
# Epoch [33/500] | Generator Loss: 57.0449 | Discriminator S Loss: 0.0013 | Discriminator H Loss: 0.0003
# Epoch [34/500] | Generator Loss: 37.8579 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0002
# Epoch [35/500] | Generator Loss: 33.0337 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0003
# Epoch [36/500] | Generator Loss: 50.3142 | Discriminator S Loss: 0.0014 | Discriminator H Loss: 0.0001
# Epoch [37/500] | Generator Loss: 62.9527 | Discriminator S Loss: 0.0019 | Discriminator H Loss: 0.0002
# Epoch [38/500] | Generator Loss: 32.1075 | Discriminator S Loss: 0.0031 | Discriminator H Loss: 0.0008
# Epoch [39/500] | Generator Loss: 26.9806 | Discriminator S Loss: 0.0020 | Discriminator H Loss: 0.0000
# Epoch [40/500] | Generator Loss: 41.6652 | Discriminator S Loss: 0.0022 | Discriminator H Loss: 0.0004
# Validation | Generator Loss: 1.8984 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0009
# Epoch [41/500] | Generator Loss: 44.1780 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0004
# Epoch [42/500] | Generator Loss: 28.0378 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0011
# Epoch [43/500] | Generator Loss: 36.3185 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0005
# Epoch [44/500] | Generator Loss: 44.7090 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0007
# Epoch [45/500] | Generator Loss: 42.7873 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0007
# Epoch [46/500] | Generator Loss: 32.2842 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0005
# Epoch [47/500] | Generator Loss: 37.8372 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0012
# Epoch [48/500] | Generator Loss: 44.5367 | Discriminator S Loss: 0.0009 | Discriminator H Loss: 0.0001
# Epoch [49/500] | Generator Loss: 35.3200 | Discriminator S Loss: 0.0009 | Discriminator H Loss: 0.0010
# Epoch [50/500] | Generator Loss: 36.9498 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 1.8545 | Discriminator S Loss: 0.0014 | Discriminator H Loss: 0.0004
# Epoch [51/500] | Generator Loss: 35.8113 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0006
# Epoch [52/500] | Generator Loss: 39.6289 | Discriminator S Loss: 0.0009 | Discriminator H Loss: 0.0002
# Epoch [53/500] | Generator Loss: 34.3139 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0004
# Epoch [54/500] | Generator Loss: 35.5930 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0011
# Epoch [55/500] | Generator Loss: 40.5373 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0003
# Epoch [56/500] | Generator Loss: 37.6068 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0003
# Epoch [57/500] | Generator Loss: 38.0156 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Epoch [58/500] | Generator Loss: 37.1713 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0005
# Epoch [59/500] | Generator Loss: 35.4314 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [60/500] | Generator Loss: 38.3985 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 1.9154 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0002
# Epoch [61/500] | Generator Loss: 35.8740 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Epoch [62/500] | Generator Loss: 33.9725 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0003
# Epoch [63/500] | Generator Loss: 39.7084 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Epoch [64/500] | Generator Loss: 34.7530 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0002
# Epoch [65/500] | Generator Loss: 35.2867 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0003
# Epoch [66/500] | Generator Loss: 37.6060 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [67/500] | Generator Loss: 37.8700 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0001
# Epoch [68/500] | Generator Loss: 34.8682 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0004
# Epoch [69/500] | Generator Loss: 34.1314 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [70/500] | Generator Loss: 43.1731 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 1.9194 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0002
# Epoch [71/500] | Generator Loss: 31.1080 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Epoch [72/500] | Generator Loss: 33.1389 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [73/500] | Generator Loss: 42.9097 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [74/500] | Generator Loss: 33.3916 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0001
# Epoch [75/500] | Generator Loss: 35.4973 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [76/500] | Generator Loss: 37.7352 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Epoch [77/500] | Generator Loss: 36.1232 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [78/500] | Generator Loss: 37.9817 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [79/500] | Generator Loss: 35.7195 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [80/500] | Generator Loss: 32.6936 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.8505 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0004
# Epoch [81/500] | Generator Loss: 40.9210 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [82/500] | Generator Loss: 35.4905 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [83/500] | Generator Loss: 32.2927 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0010
# Epoch [84/500] | Generator Loss: 39.4460 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [85/500] | Generator Loss: 36.0646 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0007
# Epoch [86/500] | Generator Loss: 34.4128 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [87/500] | Generator Loss: 32.6922 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [88/500] | Generator Loss: 43.0653 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [89/500] | Generator Loss: 36.8566 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0004
# Epoch [90/500] | Generator Loss: 28.4093 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0005
# Validation | Generator Loss: 1.7981 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0011
# Epoch [91/500] | Generator Loss: 44.5616 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [92/500] | Generator Loss: 38.3205 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [93/500] | Generator Loss: 25.9583 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Epoch [94/500] | Generator Loss: 39.9946 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [95/500] | Generator Loss: 43.3393 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0005
# Epoch [96/500] | Generator Loss: 25.6840 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [97/500] | Generator Loss: 32.2290 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [98/500] | Generator Loss: 50.2450 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [99/500] | Generator Loss: 26.2907 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [100/500] | Generator Loss: 27.2109 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 1.8960 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [101/500] | Generator Loss: 51.4526 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [102/500] | Generator Loss: 28.2119 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [103/500] | Generator Loss: 24.8738 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [104/500] | Generator Loss: 49.6992 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [105/500] | Generator Loss: 30.7900 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [106/500] | Generator Loss: 24.6494 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [107/500] | Generator Loss: 43.9344 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [108/500] | Generator Loss: 36.3325 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [109/500] | Generator Loss: 24.7834 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [110/500] | Generator Loss: 36.8248 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.8533 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0004
# Epoch [111/500] | Generator Loss: 42.7952 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [112/500] | Generator Loss: 24.8081 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [113/500] | Generator Loss: 31.9216 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [114/500] | Generator Loss: 48.4204 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0004
# Epoch [115/500] | Generator Loss: 25.1635 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [116/500] | Generator Loss: 28.1119 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0006
# Epoch [117/500] | Generator Loss: 49.7868 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [118/500] | Generator Loss: 25.7302 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [119/500] | Generator Loss: 25.7096 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [120/500] | Generator Loss: 49.6073 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.9244 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [121/500] | Generator Loss: 26.2370 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [122/500] | Generator Loss: 24.2298 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [123/500] | Generator Loss: 45.0954 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [124/500] | Generator Loss: 33.8580 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [125/500] | Generator Loss: 24.1581 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [126/500] | Generator Loss: 35.2824 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [127/500] | Generator Loss: 43.7095 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [128/500] | Generator Loss: 24.7686 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [129/500] | Generator Loss: 28.2040 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [130/500] | Generator Loss: 47.3306 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8720 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [131/500] | Generator Loss: 26.7239 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [132/500] | Generator Loss: 25.2690 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [133/500] | Generator Loss: 43.5902 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [134/500] | Generator Loss: 34.4648 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [135/500] | Generator Loss: 24.8276 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0007
# Epoch [136/500] | Generator Loss: 36.5127 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [137/500] | Generator Loss: 41.0650 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [138/500] | Generator Loss: 26.2208 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [139/500] | Generator Loss: 32.3602 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [140/500] | Generator Loss: 41.9302 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.9348 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [141/500] | Generator Loss: 33.7552 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [142/500] | Generator Loss: 28.0749 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [143/500] | Generator Loss: 35.3799 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [144/500] | Generator Loss: 42.8663 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [145/500] | Generator Loss: 26.5007 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [146/500] | Generator Loss: 34.1900 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [147/500] | Generator Loss: 41.4177 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [148/500] | Generator Loss: 31.2768 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [149/500] | Generator Loss: 30.7263 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [150/500] | Generator Loss: 37.0946 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.8458 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [151/500] | Generator Loss: 40.3128 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [152/500] | Generator Loss: 27.7062 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [153/500] | Generator Loss: 34.4238 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [154/500] | Generator Loss: 42.8814 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [155/500] | Generator Loss: 28.2284 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [156/500] | Generator Loss: 34.5374 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [157/500] | Generator Loss: 35.3529 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [158/500] | Generator Loss: 38.5621 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [159/500] | Generator Loss: 31.4566 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [160/500] | Generator Loss: 31.2851 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.9112 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [161/500] | Generator Loss: 42.0916 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [162/500] | Generator Loss: 29.9195 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [163/500] | Generator Loss: 33.9512 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [164/500] | Generator Loss: 31.1523 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [165/500] | Generator Loss: 40.3295 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [166/500] | Generator Loss: 33.8693 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [167/500] | Generator Loss: 26.9723 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [168/500] | Generator Loss: 40.1683 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [169/500] | Generator Loss: 35.8614 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [170/500] | Generator Loss: 30.6017 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.8348 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [171/500] | Generator Loss: 32.1001 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [172/500] | Generator Loss: 39.6745 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [173/500] | Generator Loss: 33.5427 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [174/500] | Generator Loss: 27.9271 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [175/500] | Generator Loss: 40.7416 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [176/500] | Generator Loss: 36.2311 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [177/500] | Generator Loss: 26.2203 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [178/500] | Generator Loss: 36.9650 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [179/500] | Generator Loss: 38.7762 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [180/500] | Generator Loss: 29.7111 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.8303 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0004
# Epoch [181/500] | Generator Loss: 32.6977 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [182/500] | Generator Loss: 37.3358 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [183/500] | Generator Loss: 32.6838 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [184/500] | Generator Loss: 28.6066 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [185/500] | Generator Loss: 38.5717 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [186/500] | Generator Loss: 37.0269 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [187/500] | Generator Loss: 25.5374 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [188/500] | Generator Loss: 36.3575 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [189/500] | Generator Loss: 39.6082 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [190/500] | Generator Loss: 28.5499 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.8644 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [191/500] | Generator Loss: 32.8916 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [192/500] | Generator Loss: 41.0546 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [193/500] | Generator Loss: 32.8280 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [194/500] | Generator Loss: 30.0303 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [195/500] | Generator Loss: 39.3758 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [196/500] | Generator Loss: 38.6454 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [197/500] | Generator Loss: 27.3473 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [198/500] | Generator Loss: 36.9814 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [199/500] | Generator Loss: 40.9419 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [200/500] | Generator Loss: 27.3180 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.7937 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [201/500] | Generator Loss: 35.2374 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [202/500] | Generator Loss: 39.8174 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [203/500] | Generator Loss: 32.2454 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [204/500] | Generator Loss: 32.0738 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [205/500] | Generator Loss: 39.1480 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [206/500] | Generator Loss: 34.3206 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [207/500] | Generator Loss: 26.9296 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [208/500] | Generator Loss: 40.5079 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [209/500] | Generator Loss: 31.8409 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [210/500] | Generator Loss: 32.6098 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.8530 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [211/500] | Generator Loss: 35.4678 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [212/500] | Generator Loss: 36.6501 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [213/500] | Generator Loss: 33.9418 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [214/500] | Generator Loss: 28.5189 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [215/500] | Generator Loss: 41.8200 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [216/500] | Generator Loss: 31.5901 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [217/500] | Generator Loss: 31.3381 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [218/500] | Generator Loss: 41.7758 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [219/500] | Generator Loss: 29.3506 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [220/500] | Generator Loss: 34.3142 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.8470 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [221/500] | Generator Loss: 37.0803 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [222/500] | Generator Loss: 37.3036 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [223/500] | Generator Loss: 31.5230 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [224/500] | Generator Loss: 33.2381 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [225/500] | Generator Loss: 41.9147 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [226/500] | Generator Loss: 28.5883 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [227/500] | Generator Loss: 34.4801 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [228/500] | Generator Loss: 38.5592 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [229/500] | Generator Loss: 34.0118 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [230/500] | Generator Loss: 32.6433 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8622 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [231/500] | Generator Loss: 37.7034 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [232/500] | Generator Loss: 38.1363 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [233/500] | Generator Loss: 27.6768 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [234/500] | Generator Loss: 37.1941 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [235/500] | Generator Loss: 40.3222 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [236/500] | Generator Loss: 31.0492 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [237/500] | Generator Loss: 33.6043 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [238/500] | Generator Loss: 41.4193 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [239/500] | Generator Loss: 34.8859 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [240/500] | Generator Loss: 28.4637 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8181 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [241/500] | Generator Loss: 41.6669 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [242/500] | Generator Loss: 39.2589 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [243/500] | Generator Loss: 28.0083 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [244/500] | Generator Loss: 37.0109 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [245/500] | Generator Loss: 44.9889 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [246/500] | Generator Loss: 30.4541 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [247/500] | Generator Loss: 28.6643 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [248/500] | Generator Loss: 46.8113 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [249/500] | Generator Loss: 34.9739 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [250/500] | Generator Loss: 27.7089 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.8429 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [251/500] | Generator Loss: 40.7723 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [252/500] | Generator Loss: 44.1422 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [253/500] | Generator Loss: 28.1108 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [254/500] | Generator Loss: 30.4581 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [255/500] | Generator Loss: 49.9018 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [256/500] | Generator Loss: 30.7246 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [257/500] | Generator Loss: 28.0499 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [258/500] | Generator Loss: 45.8013 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [259/500] | Generator Loss: 39.6620 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [260/500] | Generator Loss: 27.9974 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8303 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [261/500] | Generator Loss: 34.6204 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [262/500] | Generator Loss: 49.7342 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [263/500] | Generator Loss: 28.1331 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [264/500] | Generator Loss: 28.2131 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [265/500] | Generator Loss: 50.9911 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [266/500] | Generator Loss: 33.6071 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [267/500] | Generator Loss: 28.3010 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [268/500] | Generator Loss: 39.5205 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [269/500] | Generator Loss: 46.3296 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [270/500] | Generator Loss: 29.1934 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8298 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [271/500] | Generator Loss: 32.0456 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [272/500] | Generator Loss: 46.2567 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [273/500] | Generator Loss: 35.8808 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [274/500] | Generator Loss: 28.4470 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [275/500] | Generator Loss: 44.4801 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [276/500] | Generator Loss: 35.3969 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [277/500] | Generator Loss: 32.3461 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [278/500] | Generator Loss: 41.9833 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [279/500] | Generator Loss: 34.6135 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [280/500] | Generator Loss: 36.1627 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8322 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [281/500] | Generator Loss: 35.7849 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [282/500] | Generator Loss: 40.5475 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [283/500] | Generator Loss: 31.4727 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [284/500] | Generator Loss: 36.1622 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [285/500] | Generator Loss: 44.4075 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [286/500] | Generator Loss: 28.3960 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [287/500] | Generator Loss: 36.7825 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [288/500] | Generator Loss: 44.8127 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [289/500] | Generator Loss: 32.1188 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0004
# Epoch [290/500] | Generator Loss: 34.3345 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8592 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [291/500] | Generator Loss: 46.4064 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [292/500] | Generator Loss: 36.3778 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [293/500] | Generator Loss: 29.9509 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [294/500] | Generator Loss: 42.3417 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [295/500] | Generator Loss: 41.8368 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [296/500] | Generator Loss: 28.5088 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [297/500] | Generator Loss: 37.3273 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [298/500] | Generator Loss: 45.5253 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [299/500] | Generator Loss: 28.9064 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [300/500] | Generator Loss: 34.9967 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8939 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [301/500] | Generator Loss: 47.1802 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [302/500] | Generator Loss: 30.5202 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [303/500] | Generator Loss: 31.1219 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [304/500] | Generator Loss: 47.6204 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [305/500] | Generator Loss: 36.2760 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [306/500] | Generator Loss: 28.5727 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [307/500] | Generator Loss: 43.2669 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [308/500] | Generator Loss: 42.9579 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [309/500] | Generator Loss: 28.5537 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [310/500] | Generator Loss: 34.2362 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8105 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [311/500] | Generator Loss: 49.9672 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [312/500] | Generator Loss: 28.3652 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [313/500] | Generator Loss: 31.0769 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [314/500] | Generator Loss: 49.9910 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [315/500] | Generator Loss: 31.6091 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [316/500] | Generator Loss: 28.7637 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [317/500] | Generator Loss: 44.5693 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [318/500] | Generator Loss: 38.5777 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [319/500] | Generator Loss: 28.2337 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [320/500] | Generator Loss: 39.6734 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.9116 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [321/500] | Generator Loss: 43.1023 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [322/500] | Generator Loss: 29.0555 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [323/500] | Generator Loss: 32.5269 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [324/500] | Generator Loss: 47.0255 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [325/500] | Generator Loss: 34.3341 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [326/500] | Generator Loss: 28.5609 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [327/500] | Generator Loss: 44.5595 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [328/500] | Generator Loss: 40.0246 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [329/500] | Generator Loss: 28.4349 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [330/500] | Generator Loss: 37.4852 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8675 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [331/500] | Generator Loss: 48.0002 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [332/500] | Generator Loss: 29.2065 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [333/500] | Generator Loss: 31.7307 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [334/500] | Generator Loss: 50.4723 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [335/500] | Generator Loss: 32.1171 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [336/500] | Generator Loss: 29.3786 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [337/500] | Generator Loss: 46.8968 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [338/500] | Generator Loss: 37.6737 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [339/500] | Generator Loss: 29.0413 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [340/500] | Generator Loss: 41.0187 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8653 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [341/500] | Generator Loss: 44.9663 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [342/500] | Generator Loss: 29.0053 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [343/500] | Generator Loss: 35.8549 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [344/500] | Generator Loss: 47.7749 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [345/500] | Generator Loss: 33.1124 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [346/500] | Generator Loss: 32.6630 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [347/500] | Generator Loss: 44.0497 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [348/500] | Generator Loss: 36.6280 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [349/500] | Generator Loss: 31.1888 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [350/500] | Generator Loss: 44.1379 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.8551 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [351/500] | Generator Loss: 36.8965 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [352/500] | Generator Loss: 33.3116 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [353/500] | Generator Loss: 43.7969 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [354/500] | Generator Loss: 33.4765 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [355/500] | Generator Loss: 36.5073 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [356/500] | Generator Loss: 41.4830 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [357/500] | Generator Loss: 34.9971 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [358/500] | Generator Loss: 36.1086 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [359/500] | Generator Loss: 40.7226 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [360/500] | Generator Loss: 39.4321 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8612 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [361/500] | Generator Loss: 32.2146 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [362/500] | Generator Loss: 39.7844 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [363/500] | Generator Loss: 43.9814 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [364/500] | Generator Loss: 28.6644 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [365/500] | Generator Loss: 37.6176 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [366/500] | Generator Loss: 45.2308 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [367/500] | Generator Loss: 29.7607 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [368/500] | Generator Loss: 36.5531 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [369/500] | Generator Loss: 43.0172 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [370/500] | Generator Loss: 37.6185 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8611 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [371/500] | Generator Loss: 34.1711 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [372/500] | Generator Loss: 38.9303 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [373/500] | Generator Loss: 42.8347 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [374/500] | Generator Loss: 31.9046 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [375/500] | Generator Loss: 36.7520 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [376/500] | Generator Loss: 41.6570 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [377/500] | Generator Loss: 34.9732 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [378/500] | Generator Loss: 36.8444 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [379/500] | Generator Loss: 37.1111 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [380/500] | Generator Loss: 40.2497 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8772 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [381/500] | Generator Loss: 34.0474 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [382/500] | Generator Loss: 35.5710 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [383/500] | Generator Loss: 44.0985 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0031
# Epoch [384/500] | Generator Loss: 30.3787 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [385/500] | Generator Loss: 36.8670 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [386/500] | Generator Loss: 41.1198 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [387/500] | Generator Loss: 38.1584 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [388/500] | Generator Loss: 34.0567 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [389/500] | Generator Loss: 37.1692 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [390/500] | Generator Loss: 44.0940 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8694 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [391/500] | Generator Loss: 28.6791 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [392/500] | Generator Loss: 36.7353 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [393/500] | Generator Loss: 42.8309 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [394/500] | Generator Loss: 35.4910 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [395/500] | Generator Loss: 32.3734 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [396/500] | Generator Loss: 42.4270 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [397/500] | Generator Loss: 40.5125 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [398/500] | Generator Loss: 29.6074 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [399/500] | Generator Loss: 39.4150 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [400/500] | Generator Loss: 42.0788 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8621 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [401/500] | Generator Loss: 34.9536 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [402/500] | Generator Loss: 32.8998 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0004
# Epoch [403/500] | Generator Loss: 43.5507 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [404/500] | Generator Loss: 37.3413 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [405/500] | Generator Loss: 29.1126 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [406/500] | Generator Loss: 42.9185 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [407/500] | Generator Loss: 38.7552 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [408/500] | Generator Loss: 33.8598 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [409/500] | Generator Loss: 36.5332 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [410/500] | Generator Loss: 42.1192 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8756 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [411/500] | Generator Loss: 37.2101 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [412/500] | Generator Loss: 29.3923 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [413/500] | Generator Loss: 44.5842 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [414/500] | Generator Loss: 38.8278 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [415/500] | Generator Loss: 29.1280 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [416/500] | Generator Loss: 40.1456 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [417/500] | Generator Loss: 43.4474 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [418/500] | Generator Loss: 32.5862 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [419/500] | Generator Loss: 32.3768 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [420/500] | Generator Loss: 46.4622 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8641 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [421/500] | Generator Loss: 36.1133 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [422/500] | Generator Loss: 29.1546 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [423/500] | Generator Loss: 43.8148 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [424/500] | Generator Loss: 41.3217 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [425/500] | Generator Loss: 29.7039 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [426/500] | Generator Loss: 36.6168 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [427/500] | Generator Loss: 46.5881 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [428/500] | Generator Loss: 34.5806 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [429/500] | Generator Loss: 29.7454 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [430/500] | Generator Loss: 44.7522 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.9102 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [431/500] | Generator Loss: 39.3394 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [432/500] | Generator Loss: 28.9331 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [433/500] | Generator Loss: 40.0031 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [434/500] | Generator Loss: 45.0319 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [435/500] | Generator Loss: 29.7127 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [436/500] | Generator Loss: 34.5340 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [437/500] | Generator Loss: 47.1154 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [438/500] | Generator Loss: 34.9918 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [439/500] | Generator Loss: 31.1578 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0008
# Epoch [440/500] | Generator Loss: 44.5155 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8662 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Epoch [441/500] | Generator Loss: 38.3613 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [442/500] | Generator Loss: 29.3020 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [443/500] | Generator Loss: 41.9833 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [444/500] | Generator Loss: 44.2768 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [445/500] | Generator Loss: 29.4040 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [446/500] | Generator Loss: 34.6466 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [447/500] | Generator Loss: 49.9030 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [448/500] | Generator Loss: 30.9163 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [449/500] | Generator Loss: 31.3690 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [450/500] | Generator Loss: 48.0525 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8833 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Epoch [451/500] | Generator Loss: 37.4355 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [452/500] | Generator Loss: 29.4491 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [453/500] | Generator Loss: 43.3266 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [454/500] | Generator Loss: 42.6110 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [455/500] | Generator Loss: 29.7039 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [456/500] | Generator Loss: 39.5965 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [457/500] | Generator Loss: 45.5501 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [458/500] | Generator Loss: 30.4999 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [459/500] | Generator Loss: 34.0119 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [460/500] | Generator Loss: 46.6166 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8382 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [461/500] | Generator Loss: 34.4445 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [462/500] | Generator Loss: 30.0857 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [463/500] | Generator Loss: 45.6431 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0173
# Epoch [464/500] | Generator Loss: 37.5239 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [465/500] | Generator Loss: 28.9914 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [466/500] | Generator Loss: 44.3004 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [467/500] | Generator Loss: 39.1678 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [468/500] | Generator Loss: 30.1590 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [469/500] | Generator Loss: 39.6774 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [470/500] | Generator Loss: 41.7323 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.9250 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [471/500] | Generator Loss: 33.9179 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [472/500] | Generator Loss: 36.4292 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [473/500] | Generator Loss: 38.5149 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [474/500] | Generator Loss: 37.0429 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [475/500] | Generator Loss: 36.0740 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [476/500] | Generator Loss: 37.4368 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [477/500] | Generator Loss: 35.7123 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [478/500] | Generator Loss: 40.6896 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [479/500] | Generator Loss: 35.5320 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [480/500] | Generator Loss: 37.3195 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.8059 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [481/500] | Generator Loss: 35.7259 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [482/500] | Generator Loss: 40.9247 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [483/500] | Generator Loss: 35.7853 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [484/500] | Generator Loss: 34.7976 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0093
# Epoch [485/500] | Generator Loss: 41.8277 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [486/500] | Generator Loss: 33.8070 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [487/500] | Generator Loss: 37.3783 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [488/500] | Generator Loss: 37.1776 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [489/500] | Generator Loss: 35.3772 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [490/500] | Generator Loss: 36.8015 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.7832 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [491/500] | Generator Loss: 39.6632 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [492/500] | Generator Loss: 33.4177 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [493/500] | Generator Loss: 35.7729 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [494/500] | Generator Loss: 45.0474 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [495/500] | Generator Loss: 28.5252 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [496/500] | Generator Loss: 36.2600 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [497/500] | Generator Loss: 47.6917 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [498/500] | Generator Loss: 28.8720 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [499/500] | Generator Loss: 32.1393 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [500/500] | Generator Loss: 48.7525 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 1.9113 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001

# %%
def reconstruct_hidden_image(generator_H2S, generator_S2H, cover_image, hidden_image):
    device = cover_image.device
    # Real stego image
    stego_image = dwt_embed(cover_image, hidden_image)

    # Reconstructed hidden image
    reconstructed_hidden_image = generator_S2H(stego_image.to(device)).detach()
    
    return reconstructed_hidden_image.cpu()

def load_saved_dicts(generator_H2S, generator_S2H, discriminator_S, discriminator_H, optimizer_G, optimizer_S, optimizer_H, flag):
    # Save the model state_dict
    generator_H2S.load_state_dict(torch.load(f'./model_params/DWT/H2S/generator_H2S_epoch_{flag}.pth'))
    generator_S2H.load_state_dict(torch.load(f'./model_params/DWT/S2H/generator_S2H_epoch_{flag}.pth'))
    discriminator_S.load_state_dict(torch.load(f'./model_params/DWT/DS/discriminator_S_epoch_{flag}.pth'))
    discriminator_H.load_state_dict(torch.load(f'./model_params/DWT/DH/discriminator_H_epoch_{flag}.pth'))
    # Also optimizers
    optimizer_G.load_state_dict(torch.load(f'./model_params/DWT/optimizer/G/optimizer_G_{flag}.pth'))
    optimizer_S.load_state_dict(torch.load(f'./model_params/DWT/optimizer/S/optimizer_S_{flag}.pth'))
    optimizer_H.load_state_dict(torch.load(f'./model_params/DWT/optimizer/H/optimizer_H_{flag}.pth'))

# %%
def reconstruct_hidden_images(generator_H2S, generator_S2H, test_cover_loader, test_stego_loader, output_dir, flag):
    to_pil_image = transforms.ToPILImage()
    
    for i, (cover_data, stego_data) in enumerate(zip(test_cover_loader, test_stego_loader)):
        cover_image_tensor, _ = cover_data
        stego_image_tensor, _ = stego_data
        
        # Move tensors to the appropriate device
        device = torch.device("cuda")
        cover_image_tensor = cover_image_tensor.to(device)
        stego_image_tensor = stego_image_tensor.to(device)
        
        # Reconstruct the hidden image
        reconstructed_hidden_image = reconstruct_hidden_image(generator_H2S, generator_S2H, cover_image_tensor, stego_image_tensor)
        
        # Convert the reconstructed hidden image back to a PIL Image
        reconstructed_hidden_image_pil = to_pil_image(reconstructed_hidden_image.squeeze(0))
        
        # Save the reconstructed hidden image
        output_path = os.path.join(output_dir, f"{i}.png")
        reconstructed_hidden_image_pil.save(output_path)

# %%
# This area is for initialing and load the saved model

# Instantiate the generators and discriminators
generator_H2S = Generator()
generator_S2H = Generator()


discriminator_S = Discriminator()
discriminator_H = Discriminator()


# Set device
device = torch.device("cuda")

generator_H2S.to(device)
generator_S2H.to(device)

discriminator_H.to(device)
discriminator_S.to(device)


# Define the optimizers
optimizer_G = optim.Adam(list(generator_H2S.parameters()) + list(generator_S2H.parameters()), lr=0.0005, betas=(0.5, 0.999))


optimizer_S = optim.Adam(discriminator_S.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_H = optim.Adam(discriminator_H.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Define the loss functions
criterion_gan = torch.nn.MSELoss()
criterion_cycle = torch.nn.L1Loss()

# %%
def change_lr(optimizer_G, optimizer_H, optimizer_S, flag):
    # change learning rate to specific value
    optimizer_G_state_dict = torch.load(f'./model_params/DWT/optimizer/G/optimizer_G_{flag}.pth')
    optimizer_H_state_dict = torch.load(f'./model_params/DWT/optimizer/H/optimizer_H_{flag}.pth')
    optimizer_S_state_dict = torch.load(f'./model_params/DWT/optimizer/S/optimizer_S_{flag}.pth')
    
    optimizer_G_state_dict['param_groups'][0]['lr'] = 0.001
    optimizer_H_state_dict['param_groups'][0]['lr'] = 0.00001
    optimizer_S_state_dict['param_groups'][0]['lr'] = 0.00001

    optimizer_G.load_state_dict(optimizer_G_state_dict)
    optimizer_H.load_state_dict(optimizer_H_state_dict)
    optimizer_S.load_state_dict(optimizer_S_state_dict)

# %%
# reconstruct
output_dir = './reconstructed_hidden/TEST/'

load_saved_dicts(generator_H2S, generator_S2H, discriminator_S, discriminator_H, optimizer_G, optimizer_S, optimizer_H, flag=flag)

# change lr at epoch 1000
# change_lr(optimizer_G, optimizer_C, optimizer_S, flag=flag)

flag = 300
# reconstruct at epoch flag
reconstruct_hidden_images(generator_H2S, generator_S2H, test_cover_loader, test_stego_loader, output_dir, flag)

# %%
import cv2
import os

# Specify the directory containing the images
directory = './reconstructed_hidden/TEST'

# Loop through each file in the directory
for filename in os.listdir(directory):

    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.png'):

        # Read the image
        img = cv2.imread(os.path.join(directory, filename))

        # Convert the image to grayscale
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Write the grayscale image back to the same file
        cv2.imwrite(os.path.join(directory, filename), gray_img)
