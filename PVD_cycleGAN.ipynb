# %%
import torch
import os
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from torchvision.datasets import ImageFolder
from itertools import cycle
from PIL import Image
from torchvision.utils import save_image
import numpy as np
import torchvision.utils as vutils
import cv2

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1),
            nn.InstanceNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1),
            nn.InstanceNorm2d(in_channels),
        )

    def forward(self, x):
        return x + self.block(x)

class Generator(nn.Module):
    def __init__(self, num_res_blocks=6):
        super(Generator, self).__init__()
        
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.InstanceNorm2d(256),
            nn.ReLU(inplace=True),
        )

        res_blocks = [ResidualBlock(256) for _ in range(num_res_blocks)]
        self.residual_blocks = nn.Sequential(*res_blocks)

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 3, kernel_size=3, stride=1, padding=1),
            nn.Tanh(),
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.residual_blocks(x)
        x = self.decoder(x)
        return x

# %%
# PatchGAN Discriminator class
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.InstanceNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.InstanceNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.InstanceNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(512, 1, kernel_size=3, stride=1, padding=1),
        )

    def forward(self, x):
        return self.layers(x).view(x.size(0), -1)

# %%
def pvd_embed(cover_image, secret_image):
    device = cover_image.device
    
    cover_image_np = tensor_to_np(cover_image.cpu())
    secret_image_np = tensor_to_np(secret_image.cpu())
    
    # batch_size, channel, height, width
    _, _, height, width = cover_image_np.shape
    stego_img = np.zeros((1, 3, height, width), dtype=np.uint8)
    

    for c in range(3):
        for i in range(height):
            for j in range(width):
                cover_pixel = int(cover_image_np[0, c, i, j])
                secret_pixel = int(secret_image_np[0, c, i, j])

                stego_pixel = (cover_pixel & 0xFE) | (secret_pixel >> 7)
                stego_img[0, c, i, j] = stego_pixel

    stego_img_tensor = np_to_tensor(stego_img, device)
    return stego_img_tensor


def pvd_extract(stego_image):
    device = stego_image.device
    
    stego_image_np = tensor_to_np(stego_image.cpu())
    
    _, _, height, width = stego_image_np.shape
    extracted_img = np.zeros((1, 3, height, width), dtype=np.uint8)

    for c in range(3):
        for i in range(height):
            for j in range(width):
                stego_pixel = int(stego_image_np[0, c, i, j])

                secret_pixel = ((stego_pixel & 0x01) << 7)
                extracted_img[0, c, i, j] = secret_pixel

    extracted_img_tensor = np_to_tensor(extracted_img, device)
    return extracted_img_tensor

def tensor_to_np(tensor):
    return tensor.detach().cpu().numpy()

def np_to_tensor(array, device):
    return torch.tensor(array, device=device, dtype=torch.float32)

# %%
def train(generator_H2S, generator_S2H,
          discriminator_H, discriminator_S,
          cover_loader, stego_loader, hidden_loader,
          val_cover_loader, val_stego_loader, val_hidden_loader, device, 
          optimizer_G,
          optimizer_H, optimizer_S, 
          num_epochs, flag):

    for epoch in range(num_epochs):
        for cover, stego, hidden in zip(cover_loader, stego_loader, hidden_loader):
            cover_img, _ = cover
            stego_img, _ = stego
            hidden_img, _ = hidden
            
            cover_img = cover_img.to(device)
            stego_img = stego_img.to(device)
            hidden_img = hidden_img.to(device)

            # --------------------
            # Train the generators
            # --------------------
            
            # Identity loss
            same_hidden = generator_S2H(hidden_img)
            loss_identity_H = criterion_cycle(same_hidden, hidden_img) * 5.0
            
            same_stego = generator_H2S(stego_img)
            loss_identity_S = criterion_cycle(same_stego, stego_img) * 5.0

            # GAN loss
            fake_hidden = generator_S2H(stego_img)
            pred_fake_hidden = discriminator_H(fake_hidden)
            loss_gan_S2H = criterion_gan(pred_fake_hidden, torch.ones_like(pred_fake_hidden))

            fake_stego = generator_H2S(hidden_img)
            pred_fake_stego = discriminator_S(fake_stego)
            loss_gan_H2S = criterion_gan(pred_fake_stego, torch.ones_like(pred_fake_stego))

            # Cycle loss
            
            # It is lossy, so we only need to learn lossy output    
            """
            recovered_stego = generator_H2S(fake_hidden)
            pvd_recovered_stego = pvd_embed(cover_img, fake_hidden)
            loss_cycle_S = criterion_cycle(recovered_stego, pvd_recovered_stego) * 10.0
            """

            recovered_hidden = generator_S2H(fake_stego)
            pvd_recovered_hidden = pvd_extract(fake_stego)
            loss_cycle_H = criterion_cycle(recovered_hidden, pvd_recovered_hidden) * 10.0

            # Total generator loss
            total_g_loss = loss_identity_H + loss_identity_S + loss_gan_S2H + loss_gan_H2S + loss_cycle_H
            total_g_loss.backward()
            
            optimizer_G.step()
            
            # ------------------------
            # Train the discriminators
            # ------------------------
            
            optimizer_H.zero_grad()
            optimizer_S.zero_grad()
            
            # Discriminator S
            
            # Real loss
            pred_real_stego = discriminator_S(stego_img)
            loss_d_real_stego = criterion_gan(pred_real_stego, torch.ones_like(pred_real_stego))

            # Fake loss
            fake_stego.detach_()
            pred_fake_stego = discriminator_S(fake_stego)
            loss_d_fake_stego = criterion_gan(pred_fake_stego, torch.zeros_like(pred_fake_stego))

            # Total Discriminator S loss
            total_d_s_loss = (loss_d_real_stego + loss_d_fake_stego) * 0.5
            total_d_s_loss.backward()

            optimizer_S.step()
            
            # Discriminator H
            
            # Real loss
            pred_real_hidden = discriminator_H(hidden_img)
            loss_d_real_hidden = criterion_gan(pred_real_hidden, torch.ones_like(pred_real_hidden))

            # Fake loss
            fake_hidden.detach_()
            pred_fake_hidden = discriminator_H(fake_hidden)
            loss_d_fake_hidden = criterion_gan(pred_fake_hidden, torch.zeros_like(pred_fake_hidden))

            # Total Discriminator H loss
            total_d_h_loss = (loss_d_real_hidden + loss_d_fake_hidden) * 0.5
            total_d_h_loss.backward()
            
            optimizer_H.step()


        print(f"Epoch [{epoch+1}/{num_epochs}] | Generator Loss: {total_g_loss.item():.4f} | Discriminator S Loss: {total_d_s_loss.item():.4f} | Discriminator H Loss: {total_d_h_loss.item():.4f}")

        # Save the model checkpoints periodically or implement a custom model saving logic
        if (epoch + 1) % 50 == 0:
            torch.save(generator_H2S.state_dict(), f'./model_params/PVD/H2S/generator_H2S_epoch_{flag+epoch+1}.pth')
            torch.save(generator_S2H.state_dict(), f'./model_params/PVD/S2H/generator_S2H_epoch_{flag+epoch+1}.pth')
            torch.save(discriminator_H.state_dict(), f'./model_params/PVD/DH/discriminator_H_epoch_{flag+epoch+1}.pth')
            torch.save(discriminator_S.state_dict(), f'./model_params/PVD/DS/discriminator_S_epoch_{flag+epoch+1}.pth')
            torch.save(optimizer_G.state_dict(), f'./model_params/PVD/optimizer/G/optimizer_G_{flag+epoch+1}.pth')
            torch.save(optimizer_H.state_dict(), f'./model_params/PVD/optimizer/H/optimizer_H_{flag+epoch+1}.pth')
            torch.save(optimizer_S.state_dict(), f'./model_params/PVD/optimizer/S/optimizer_S_{flag+epoch+1}.pth')
        
        if (epoch + 1) % 10 == 0:
            generator_H2S.eval()
            generator_S2H.eval()
            discriminator_H.eval()
            discriminator_S.eval()
            
            with torch.no_grad():
                for val_cover, val_stego, val_hidden in zip(val_cover_loader, val_stego_loader, val_hidden_loader):
                    val_cover_img, _ = val_cover
                    val_stego_img, _ = val_stego
                    val_hidden_img, _ = val_hidden

                    val_cover_img = val_cover_img.to(device)
                    val_stego_img = val_stego_img.to(device)
                    val_hidden_img = val_hidden_img.to(device)

                    fake_hidden = generator_S2H(val_stego_img)
                    fake_stego = generator_H2S(val_hidden_img)
                    recovered_hidden = generator_S2H(fake_stego)
                    recovered_stego = generator_H2S(fake_hidden)

                    val_g_loss = criterion_cycle(recovered_hidden, val_hidden_img) + criterion_cycle(recovered_stego, val_stego_img)
                    val_d_h_loss = criterion_gan(discriminator_H(val_hidden_img), torch.ones_like(discriminator_H(val_hidden_img))) + criterion_gan(discriminator_H(fake_hidden.detach()), torch.zeros_like(discriminator_H(fake_hidden.detach())))
                    val_d_s_loss = criterion_gan(discriminator_S(val_stego_img), torch.ones_like(discriminator_S(val_stego_img))) + criterion_gan(discriminator_S(fake_stego.detach()), torch.zeros_like(discriminator_S(fake_stego.detach())))
                    
            generator_H2S.train()
            generator_S2H.train()
            discriminator_H.train()
            discriminator_S.train()
            print(f"Validation | Generator Loss: {val_g_loss.item():.4f} | Discriminator S Loss: {val_d_s_loss.item():.4f} | Discriminator H Loss: {val_d_h_loss.item():.4f}")

# %%
# Set device
device = torch.device('cuda')

# Load the datasets
transform = transforms.Compose([
    transforms.Resize((96, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# Train set
dataset_cover =ImageFolder('./train/PVD_cover', transform=transform)
dataset_stego = ImageFolder('./train/PVD_stego', transform=transform)
dataset_hidden = ImageFolder('./train/PVD_hidden', transform=transform)

cover_loader = DataLoader(dataset_cover, batch_size=1)
stego_loader = DataLoader(dataset_stego, batch_size=1)
hidden_loader = DataLoader(dataset_hidden, batch_size=1)

# Valid set
dataset_cover_val = ImageFolder('./valid/PVD_cover', transform=transform)
dataset_stego_val = ImageFolder('./valid/PVD_stego', transform=transform)
dataset_hidden_val = ImageFolder('./valid/PVD_hidden', transform=transform)

val_cover_loader = DataLoader(dataset_cover_val, batch_size=1)
val_stego_loader = DataLoader(dataset_stego_val, batch_size=1)
val_hidden_loader = DataLoader(dataset_hidden_val, batch_size=1)

# Test set
dataset_cover_test = ImageFolder('./test/PVD_cover', transform=transform)
dataset_stego_test = ImageFolder('./test/PVD_stego', transform=transform)
dataset_hidden_test = ImageFolder('./test/PVD_hidden', transform=transform)

test_cover_loader = DataLoader(dataset_cover_test, batch_size=1)
test_stego_loader = DataLoader(dataset_stego_test, batch_size=1)
test_hidden_loader = DataLoader(dataset_hidden_test, batch_size=1)

# %%
# Instantiate the generators and discriminators
generator_H2S = Generator()
generator_S2H = Generator()

discriminator_H = Discriminator()
discriminator_S = Discriminator()


# Set device
device = torch.device("cuda")

generator_H2S.to(device)
generator_S2H.to(device)

discriminator_H.to(device)
discriminator_S.to(device)


# Define the optimizers
optimizer_G= optim.Adam(list(generator_H2S.parameters()) + list(generator_S2H.parameters()), lr=0.0005, betas=(0.5, 0.999))

optimizer_H = optim.Adam(discriminator_H.parameters(), lr=0.0001, betas=(0.5, 0.999))
optimizer_S = optim.Adam(discriminator_S.parameters(), lr=0.0001, betas=(0.5, 0.999))


# Define the loss functions
criterion_gan = torch.nn.MSELoss()
criterion_cycle = torch.nn.L1Loss()

# %%
train(generator_H2S, generator_S2H, discriminator_H, discriminator_S,
      cover_loader, stego_loader, hidden_loader, val_cover_loader, val_stego_loader, val_hidden_loader, device, optimizer_G, optimizer_H, optimizer_S, num_epochs=1000, flag=0)
# Out:
# Epoch [1/1000] | Generator Loss: 147.3317 | Discriminator S Loss: 0.0053 | Discriminator H Loss: 0.0125
# Epoch [2/1000] | Generator Loss: 128.5973 | Discriminator S Loss: 0.0022 | Discriminator H Loss: 0.0113
# Epoch [3/1000] | Generator Loss: 208.1801 | Discriminator S Loss: 0.0048 | Discriminator H Loss: 0.0314
# Epoch [4/1000] | Generator Loss: 220.0372 | Discriminator S Loss: 0.0030 | Discriminator H Loss: 0.0031
# Epoch [5/1000] | Generator Loss: 231.6017 | Discriminator S Loss: 0.0043 | Discriminator H Loss: 0.0030
# Epoch [6/1000] | Generator Loss: 239.9948 | Discriminator S Loss: 0.0071 | Discriminator H Loss: 0.0038
# Epoch [7/1000] | Generator Loss: 233.0219 | Discriminator S Loss: 0.0040 | Discriminator H Loss: 0.0041
# Epoch [8/1000] | Generator Loss: 227.8129 | Discriminator S Loss: 0.0031 | Discriminator H Loss: 0.0024
# Epoch [9/1000] | Generator Loss: 224.8888 | Discriminator S Loss: 0.0028 | Discriminator H Loss: 0.0045
# Epoch [10/1000] | Generator Loss: 222.5243 | Discriminator S Loss: 0.0031 | Discriminator H Loss: 0.0027
# Validation | Generator Loss: 1.1956 | Discriminator S Loss: 0.0021 | Discriminator H Loss: 0.0055
# Epoch [11/1000] | Generator Loss: 221.7129 | Discriminator S Loss: 0.0021 | Discriminator H Loss: 0.0052
# Epoch [12/1000] | Generator Loss: 221.8106 | Discriminator S Loss: 0.0021 | Discriminator H Loss: 0.0020
# Epoch [13/1000] | Generator Loss: 222.3406 | Discriminator S Loss: 0.0036 | Discriminator H Loss: 0.0014
# Epoch [14/1000] | Generator Loss: 222.4890 | Discriminator S Loss: 0.0027 | Discriminator H Loss: 0.0018
# Epoch [15/1000] | Generator Loss: 219.3755 | Discriminator S Loss: 0.0020 | Discriminator H Loss: 0.0013
# Epoch [16/1000] | Generator Loss: 214.1960 | Discriminator S Loss: 0.0037 | Discriminator H Loss: 0.0008
# Epoch [17/1000] | Generator Loss: 209.9426 | Discriminator S Loss: 0.0027 | Discriminator H Loss: 0.0012
# Epoch [18/1000] | Generator Loss: 207.6465 | Discriminator S Loss: 0.0026 | Discriminator H Loss: 0.0075
# Epoch [19/1000] | Generator Loss: 208.1079 | Discriminator S Loss: 0.0036 | Discriminator H Loss: 0.0019
# Epoch [20/1000] | Generator Loss: 211.3844 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0012
# Validation | Generator Loss: 1.2264 | Discriminator S Loss: 0.0014 | Discriminator H Loss: 0.0017
# Epoch [21/1000] | Generator Loss: 212.2653 | Discriminator S Loss: 0.0014 | Discriminator H Loss: 0.0019
# Epoch [22/1000] | Generator Loss: 213.6696 | Discriminator S Loss: 0.0014 | Discriminator H Loss: 0.0029
# Epoch [23/1000] | Generator Loss: 215.5806 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0008
# Epoch [24/1000] | Generator Loss: 217.8497 | Discriminator S Loss: 0.0009 | Discriminator H Loss: 0.0006
# Epoch [25/1000] | Generator Loss: 219.5800 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0005
# Epoch [26/1000] | Generator Loss: 221.0442 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0034
# Epoch [27/1000] | Generator Loss: 222.4368 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0003
# Epoch [28/1000] | Generator Loss: 220.7424 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0003
# Epoch [29/1000] | Generator Loss: 218.0608 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0011
# Epoch [30/1000] | Generator Loss: 215.8624 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0016
# Validation | Generator Loss: 1.1259 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0037
# Epoch [31/1000] | Generator Loss: 215.0141 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0008
# Epoch [32/1000] | Generator Loss: 215.0275 | Discriminator S Loss: 0.0009 | Discriminator H Loss: 0.0006
# Epoch [33/1000] | Generator Loss: 214.8315 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0007
# Epoch [34/1000] | Generator Loss: 214.5411 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0010
# Epoch [35/1000] | Generator Loss: 214.3436 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0013
# Epoch [36/1000] | Generator Loss: 215.0612 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0004
# Epoch [37/1000] | Generator Loss: 215.8427 | Discriminator S Loss: 0.0013 | Discriminator H Loss: 0.0004
# Epoch [38/1000] | Generator Loss: 217.4347 | Discriminator S Loss: 0.0020 | Discriminator H Loss: 0.0015
# Epoch [39/1000] | Generator Loss: 218.6057 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0004
# Epoch [40/1000] | Generator Loss: 220.0045 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0004
# Validation | Generator Loss: 1.1762 | Discriminator S Loss: 0.0019 | Discriminator H Loss: 0.0003
# Epoch [41/1000] | Generator Loss: 220.7917 | Discriminator S Loss: 0.0013 | Discriminator H Loss: 0.0002
# Epoch [42/1000] | Generator Loss: 220.2472 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0003
# Epoch [43/1000] | Generator Loss: 220.0621 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0016
# Epoch [44/1000] | Generator Loss: 220.2998 | Discriminator S Loss: 0.0013 | Discriminator H Loss: 0.0005
# Epoch [45/1000] | Generator Loss: 220.7351 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0004
# Epoch [46/1000] | Generator Loss: 221.3125 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0002
# Epoch [47/1000] | Generator Loss: 220.8517 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0006
# Epoch [48/1000] | Generator Loss: 220.8489 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0002
# Epoch [49/1000] | Generator Loss: 221.2845 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0004
# Epoch [50/1000] | Generator Loss: 221.9844 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0005
# Validation | Generator Loss: 1.2520 | Discriminator S Loss: 0.0016 | Discriminator H Loss: 0.0005
# Epoch [51/1000] | Generator Loss: 220.6938 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0010
# Epoch [52/1000] | Generator Loss: 220.6437 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0006
# Epoch [53/1000] | Generator Loss: 222.5258 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0010
# Epoch [54/1000] | Generator Loss: 224.2286 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0002
# Epoch [55/1000] | Generator Loss: 224.1164 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0007
# Epoch [56/1000] | Generator Loss: 223.9857 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0017
# Epoch [57/1000] | Generator Loss: 224.7142 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0003
# Epoch [58/1000] | Generator Loss: 225.1833 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0004
# Epoch [59/1000] | Generator Loss: 225.2139 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0008
# Epoch [60/1000] | Generator Loss: 224.2668 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0005
# Validation | Generator Loss: 1.0667 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0009
# Epoch [61/1000] | Generator Loss: 224.5018 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0002
# Epoch [62/1000] | Generator Loss: 225.0966 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0001
# Epoch [63/1000] | Generator Loss: 224.2816 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0002
# Epoch [64/1000] | Generator Loss: 223.8643 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0001
# Epoch [65/1000] | Generator Loss: 224.5250 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0001
# Epoch [66/1000] | Generator Loss: 224.8187 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0001
# Epoch [67/1000] | Generator Loss: 224.1993 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0002
# Epoch [68/1000] | Generator Loss: 224.2290 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0004
# Epoch [69/1000] | Generator Loss: 225.1395 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0001
# Epoch [70/1000] | Generator Loss: 225.0743 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.1226 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [71/1000] | Generator Loss: 223.2693 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0003
# Epoch [72/1000] | Generator Loss: 222.9073 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0004
# Epoch [73/1000] | Generator Loss: 222.0135 | Discriminator S Loss: 0.0018 | Discriminator H Loss: 0.0004
# Epoch [74/1000] | Generator Loss: 220.8273 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0001
# Epoch [75/1000] | Generator Loss: 219.1358 | Discriminator S Loss: 0.0014 | Discriminator H Loss: 0.0006
# Epoch [76/1000] | Generator Loss: 215.5050 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0001
# Epoch [77/1000] | Generator Loss: 211.8256 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0001
# Epoch [78/1000] | Generator Loss: 208.2366 | Discriminator S Loss: 0.0032 | Discriminator H Loss: 0.0002
# Epoch [79/1000] | Generator Loss: 207.8611 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0008
# Epoch [80/1000] | Generator Loss: 207.4938 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0004
# Validation | Generator Loss: 1.1197 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0008
# Epoch [81/1000] | Generator Loss: 205.9745 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0004
# Epoch [82/1000] | Generator Loss: 206.2986 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0003
# Epoch [83/1000] | Generator Loss: 206.4947 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Epoch [84/1000] | Generator Loss: 205.5256 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0004
# Epoch [85/1000] | Generator Loss: 204.0298 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0001
# Epoch [86/1000] | Generator Loss: 203.5979 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0002
# Epoch [87/1000] | Generator Loss: 203.1836 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [88/1000] | Generator Loss: 201.7136 | Discriminator S Loss: 0.0020 | Discriminator H Loss: 0.0003
# Epoch [89/1000] | Generator Loss: 201.9557 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0002
# Epoch [90/1000] | Generator Loss: 201.8652 | Discriminator S Loss: 0.0013 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 1.0714 | Discriminator S Loss: 0.0029 | Discriminator H Loss: 0.0002
# Epoch [91/1000] | Generator Loss: 200.6765 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0004
# Epoch [92/1000] | Generator Loss: 201.2276 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0001
# Epoch [93/1000] | Generator Loss: 201.1046 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Epoch [94/1000] | Generator Loss: 200.0311 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0016
# Epoch [95/1000] | Generator Loss: 200.7679 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0001
# Epoch [96/1000] | Generator Loss: 200.5875 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0002
# Epoch [97/1000] | Generator Loss: 200.2844 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Epoch [98/1000] | Generator Loss: 201.1211 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [99/1000] | Generator Loss: 201.0766 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [100/1000] | Generator Loss: 199.9874 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 0.9631 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0009
# Epoch [101/1000] | Generator Loss: 201.1014 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0006
# Epoch [102/1000] | Generator Loss: 200.4954 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0002
# Epoch [103/1000] | Generator Loss: 200.7608 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0006
# Epoch [104/1000] | Generator Loss: 201.5224 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0002
# Epoch [105/1000] | Generator Loss: 201.3454 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0028
# Epoch [106/1000] | Generator Loss: 202.0840 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [107/1000] | Generator Loss: 201.4691 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0001
# Epoch [108/1000] | Generator Loss: 201.1775 | Discriminator S Loss: 0.0022 | Discriminator H Loss: 0.0001
# Epoch [109/1000] | Generator Loss: 201.3743 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [110/1000] | Generator Loss: 201.1350 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 0.9874 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0003
# Epoch [111/1000] | Generator Loss: 200.2753 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [112/1000] | Generator Loss: 200.7101 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0007
# Epoch [113/1000] | Generator Loss: 200.1588 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0008
# Epoch [114/1000] | Generator Loss: 200.0270 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0005
# Epoch [115/1000] | Generator Loss: 200.0235 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0008
# Epoch [116/1000] | Generator Loss: 199.8130 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0003
# Epoch [117/1000] | Generator Loss: 199.2617 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0008
# Epoch [118/1000] | Generator Loss: 200.4378 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [119/1000] | Generator Loss: 199.3727 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0005
# Epoch [120/1000] | Generator Loss: 200.1412 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9965 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [121/1000] | Generator Loss: 199.7188 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [122/1000] | Generator Loss: 199.4198 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0001
# Epoch [123/1000] | Generator Loss: 199.6251 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [124/1000] | Generator Loss: 198.5159 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [125/1000] | Generator Loss: 198.5075 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [126/1000] | Generator Loss: 197.5448 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [127/1000] | Generator Loss: 196.8817 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0006
# Epoch [128/1000] | Generator Loss: 196.8023 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [129/1000] | Generator Loss: 196.3904 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0018
# Epoch [130/1000] | Generator Loss: 196.9604 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0003
# Validation | Generator Loss: 0.9865 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0003
# Epoch [131/1000] | Generator Loss: 196.5834 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0002
# Epoch [132/1000] | Generator Loss: 194.8596 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [133/1000] | Generator Loss: 194.8616 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [134/1000] | Generator Loss: 195.5442 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [135/1000] | Generator Loss: 194.5523 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [136/1000] | Generator Loss: 194.0875 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [137/1000] | Generator Loss: 194.0965 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0006
# Epoch [138/1000] | Generator Loss: 194.2572 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [139/1000] | Generator Loss: 193.0485 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0063
# Epoch [140/1000] | Generator Loss: 192.9331 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 0.9057 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0004
# Epoch [141/1000] | Generator Loss: 192.4357 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0007
# Epoch [142/1000] | Generator Loss: 192.5444 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0010
# Epoch [143/1000] | Generator Loss: 191.5353 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0010
# Epoch [144/1000] | Generator Loss: 192.3514 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0014
# Epoch [145/1000] | Generator Loss: 191.8157 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0004
# Epoch [146/1000] | Generator Loss: 192.8255 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Epoch [147/1000] | Generator Loss: 191.8584 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [148/1000] | Generator Loss: 190.4987 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0004
# Epoch [149/1000] | Generator Loss: 190.6795 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Epoch [150/1000] | Generator Loss: 191.3720 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 1.0144 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [151/1000] | Generator Loss: 191.0642 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [152/1000] | Generator Loss: 190.5020 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [153/1000] | Generator Loss: 190.3204 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [154/1000] | Generator Loss: 190.0567 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0004
# Epoch [155/1000] | Generator Loss: 190.7692 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [156/1000] | Generator Loss: 190.4441 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0009
# Epoch [157/1000] | Generator Loss: 189.6340 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0008
# Epoch [158/1000] | Generator Loss: 190.5084 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [159/1000] | Generator Loss: 190.9474 | Discriminator S Loss: 0.0009 | Discriminator H Loss: 0.0011
# Epoch [160/1000] | Generator Loss: 190.6445 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 1.0396 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Epoch [161/1000] | Generator Loss: 190.5694 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0001
# Epoch [162/1000] | Generator Loss: 190.3509 | Discriminator S Loss: 0.0079 | Discriminator H Loss: 0.0003
# Epoch [163/1000] | Generator Loss: 190.8293 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [164/1000] | Generator Loss: 190.3285 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [165/1000] | Generator Loss: 190.1185 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0007
# Epoch [166/1000] | Generator Loss: 190.6717 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [167/1000] | Generator Loss: 190.1629 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [168/1000] | Generator Loss: 189.5240 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [169/1000] | Generator Loss: 190.3602 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [170/1000] | Generator Loss: 189.3192 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.8758 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0001
# Epoch [171/1000] | Generator Loss: 189.5941 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0004
# Epoch [172/1000] | Generator Loss: 189.7482 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [173/1000] | Generator Loss: 190.0140 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [174/1000] | Generator Loss: 189.6093 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0004
# Epoch [175/1000] | Generator Loss: 189.7962 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [176/1000] | Generator Loss: 190.2540 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [177/1000] | Generator Loss: 189.5922 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [178/1000] | Generator Loss: 189.6565 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Epoch [179/1000] | Generator Loss: 190.0738 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [180/1000] | Generator Loss: 189.6347 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.9695 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0001
# Epoch [181/1000] | Generator Loss: 189.1966 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [182/1000] | Generator Loss: 189.5173 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [183/1000] | Generator Loss: 189.6225 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Epoch [184/1000] | Generator Loss: 188.6053 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [185/1000] | Generator Loss: 189.2560 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [186/1000] | Generator Loss: 188.3230 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [187/1000] | Generator Loss: 189.2401 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [188/1000] | Generator Loss: 188.2749 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [189/1000] | Generator Loss: 188.5367 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [190/1000] | Generator Loss: 188.4954 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 0.8449 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [191/1000] | Generator Loss: 187.6333 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0002
# Epoch [192/1000] | Generator Loss: 188.1449 | Discriminator S Loss: 0.0017 | Discriminator H Loss: 0.0002
# Epoch [193/1000] | Generator Loss: 188.3751 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [194/1000] | Generator Loss: 187.0652 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [195/1000] | Generator Loss: 188.2912 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0004
# Epoch [196/1000] | Generator Loss: 187.0770 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [200/1000] | Generator Loss: 186.9400 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9560 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Epoch [201/1000] | Generator Loss: 186.9962 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [202/1000] | Generator Loss: 187.1266 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [203/1000] | Generator Loss: 187.3871 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [204/1000] | Generator Loss: 186.7507 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0017
# Epoch [205/1000] | Generator Loss: 186.5667 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [206/1000] | Generator Loss: 187.1954 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [207/1000] | Generator Loss: 186.8186 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [208/1000] | Generator Loss: 186.5487 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [209/1000] | Generator Loss: 186.3266 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [210/1000] | Generator Loss: 186.5143 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9147 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [211/1000] | Generator Loss: 187.2022 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [212/1000] | Generator Loss: 186.1815 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [213/1000] | Generator Loss: 186.4344 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [214/1000] | Generator Loss: 186.5721 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [215/1000] | Generator Loss: 186.3776 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [216/1000] | Generator Loss: 186.2361 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [217/1000] | Generator Loss: 185.8165 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [218/1000] | Generator Loss: 186.0723 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0000
# Epoch [219/1000] | Generator Loss: 186.0111 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [220/1000] | Generator Loss: 185.2033 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.9090 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [221/1000] | Generator Loss: 185.5219 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [222/1000] | Generator Loss: 185.4751 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [223/1000] | Generator Loss: 184.2229 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [224/1000] | Generator Loss: 184.8859 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [225/1000] | Generator Loss: 184.8377 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Epoch [226/1000] | Generator Loss: 184.1569 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [227/1000] | Generator Loss: 184.3493 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [228/1000] | Generator Loss: 184.2871 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [229/1000] | Generator Loss: 184.0103 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [230/1000] | Generator Loss: 183.7283 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9241 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [231/1000] | Generator Loss: 183.3683 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [232/1000] | Generator Loss: 183.1780 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0004
# Epoch [233/1000] | Generator Loss: 183.1858 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [234/1000] | Generator Loss: 182.7234 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [235/1000] | Generator Loss: 182.2367 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [236/1000] | Generator Loss: 182.2918 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [237/1000] | Generator Loss: 182.0767 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [238/1000] | Generator Loss: 182.2097 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [239/1000] | Generator Loss: 181.8504 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [240/1000] | Generator Loss: 181.7518 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9370 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [241/1000] | Generator Loss: 182.0290 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [242/1000] | Generator Loss: 181.1893 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [243/1000] | Generator Loss: 181.6978 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [244/1000] | Generator Loss: 181.2783 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [245/1000] | Generator Loss: 181.4065 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [246/1000] | Generator Loss: 180.9733 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0004
# Epoch [247/1000] | Generator Loss: 180.4988 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0004
# Epoch [248/1000] | Generator Loss: 180.5865 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [249/1000] | Generator Loss: 180.4949 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [250/1000] | Generator Loss: 180.1841 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.8805 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [251/1000] | Generator Loss: 180.2192 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [252/1000] | Generator Loss: 179.6324 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [253/1000] | Generator Loss: 180.1406 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [254/1000] | Generator Loss: 179.4494 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [255/1000] | Generator Loss: 179.2850 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [256/1000] | Generator Loss: 179.4876 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [257/1000] | Generator Loss: 179.1652 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [258/1000] | Generator Loss: 179.1181 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [259/1000] | Generator Loss: 178.3890 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [260/1000] | Generator Loss: 178.8748 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9169 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [261/1000] | Generator Loss: 178.4468 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0000
# Epoch [262/1000] | Generator Loss: 178.0518 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0001
# Epoch [263/1000] | Generator Loss: 177.8180 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0002
# Epoch [264/1000] | Generator Loss: 177.4486 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [265/1000] | Generator Loss: 177.6613 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [266/1000] | Generator Loss: 177.1201 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [267/1000] | Generator Loss: 176.8924 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [268/1000] | Generator Loss: 177.1556 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Epoch [269/1000] | Generator Loss: 176.5045 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [270/1000] | Generator Loss: 176.3038 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0009
# Validation | Generator Loss: 0.9030 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0013
# Epoch [271/1000] | Generator Loss: 176.1880 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0004
# Epoch [272/1000] | Generator Loss: 175.6604 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [273/1000] | Generator Loss: 175.1743 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [274/1000] | Generator Loss: 175.2263 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Epoch [275/1000] | Generator Loss: 175.2445 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [276/1000] | Generator Loss: 174.9699 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [277/1000] | Generator Loss: 174.3073 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0000
# Epoch [278/1000] | Generator Loss: 174.6757 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [279/1000] | Generator Loss: 174.5374 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0000
# Epoch [280/1000] | Generator Loss: 174.0034 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.8918 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [281/1000] | Generator Loss: 174.1479 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Epoch [282/1000] | Generator Loss: 174.2673 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [283/1000] | Generator Loss: 173.9708 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0000
# Epoch [284/1000] | Generator Loss: 173.1835 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.1424
# Epoch [285/1000] | Generator Loss: 173.7189 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [286/1000] | Generator Loss: 173.9278 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [287/1000] | Generator Loss: 173.3818 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [288/1000] | Generator Loss: 173.1735 | Discriminator S Loss: 0.0010 | Discriminator H Loss: 0.0001
# Epoch [289/1000] | Generator Loss: 173.1688 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0001
# Epoch [290/1000] | Generator Loss: 172.9479 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9042 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [291/1000] | Generator Loss: 172.1485 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0002
# Epoch [292/1000] | Generator Loss: 172.3841 | Discriminator S Loss: 0.0014 | Discriminator H Loss: 0.0000
# Epoch [293/1000] | Generator Loss: 172.3916 | Discriminator S Loss: 0.0026 | Discriminator H Loss: 0.0001
# Epoch [294/1000] | Generator Loss: 171.4739 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0002
# Epoch [295/1000] | Generator Loss: 171.8959 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [296/1000] | Generator Loss: 171.2762 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [297/1000] | Generator Loss: 170.7925 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [298/1000] | Generator Loss: 171.0691 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [299/1000] | Generator Loss: 170.6371 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0000
# Epoch [300/1000] | Generator Loss: 170.5939 | Discriminator S Loss: 0.0023 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.9279 | Discriminator S Loss: 0.0037 | Discriminator H Loss: 0.0001
# Epoch [301/1000] | Generator Loss: 170.1475 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0002
# Epoch [302/1000] | Generator Loss: 169.6812 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [303/1000] | Generator Loss: 169.6254 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [304/1000] | Generator Loss: 169.3573 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [305/1000] | Generator Loss: 169.2077 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [306/1000] | Generator Loss: 169.2881 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [307/1000] | Generator Loss: 169.7762 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [308/1000] | Generator Loss: 169.9667 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0004
# Epoch [309/1000] | Generator Loss: 169.5634 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [310/1000] | Generator Loss: 169.6266 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9277 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0001
# Epoch [311/1000] | Generator Loss: 169.5890 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [312/1000] | Generator Loss: 169.1620 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0001
# Epoch [313/1000] | Generator Loss: 169.0901 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [314/1000] | Generator Loss: 169.4892 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [315/1000] | Generator Loss: 169.2767 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [316/1000] | Generator Loss: 169.2266 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [317/1000] | Generator Loss: 168.9842 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Epoch [318/1000] | Generator Loss: 169.0872 | Discriminator S Loss: 0.0013 | Discriminator H Loss: 0.0002
# Epoch [319/1000] | Generator Loss: 169.1370 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [320/1000] | Generator Loss: 168.6857 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 0.8825 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0005
# Epoch [321/1000] | Generator Loss: 168.7022 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [322/1000] | Generator Loss: 168.7760 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0004
# Epoch [323/1000] | Generator Loss: 168.7358 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0006
# Epoch [324/1000] | Generator Loss: 168.6071 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [325/1000] | Generator Loss: 168.6190 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0000
# Epoch [326/1000] | Generator Loss: 168.6174 | Discriminator S Loss: 0.0009 | Discriminator H Loss: 0.0000
# Epoch [327/1000] | Generator Loss: 168.5467 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [328/1000] | Generator Loss: 168.5630 | Discriminator S Loss: 0.0009 | Discriminator H Loss: 0.0000
# Epoch [329/1000] | Generator Loss: 168.5799 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [330/1000] | Generator Loss: 168.3598 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9004 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [331/1000] | Generator Loss: 168.2008 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [332/1000] | Generator Loss: 168.2097 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [333/1000] | Generator Loss: 167.8725 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [334/1000] | Generator Loss: 167.8076 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [335/1000] | Generator Loss: 167.8322 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [336/1000] | Generator Loss: 167.9610 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [337/1000] | Generator Loss: 168.1198 | Discriminator S Loss: 0.0009 | Discriminator H Loss: 0.0001
# Epoch [338/1000] | Generator Loss: 168.1753 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0003
# Epoch [339/1000] | Generator Loss: 168.1921 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [340/1000] | Generator Loss: 168.0312 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0004
# Validation | Generator Loss: 0.9357 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0006
# Epoch [341/1000] | Generator Loss: 168.0571 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0004
# Epoch [342/1000] | Generator Loss: 168.1632 | Discriminator S Loss: 0.0011 | Discriminator H Loss: 0.0038
# Epoch [343/1000] | Generator Loss: 168.0320 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [344/1000] | Generator Loss: 168.0194 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0000
# Epoch [345/1000] | Generator Loss: 168.0141 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [346/1000] | Generator Loss: 167.9948 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0000
# Epoch [347/1000] | Generator Loss: 167.8284 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Epoch [348/1000] | Generator Loss: 167.3481 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [349/1000] | Generator Loss: 167.6352 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0005
# Epoch [350/1000] | Generator Loss: 167.6045 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.8939 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0002
# Epoch [351/1000] | Generator Loss: 167.2348 | Discriminator S Loss: 0.0012 | Discriminator H Loss: 0.0001
# Epoch [352/1000] | Generator Loss: 167.1357 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0005
# Epoch [353/1000] | Generator Loss: 166.9413 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [354/1000] | Generator Loss: 167.2780 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [355/1000] | Generator Loss: 167.1626 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Epoch [356/1000] | Generator Loss: 167.2411 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Epoch [357/1000] | Generator Loss: 167.2365 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [358/1000] | Generator Loss: 166.9464 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [359/1000] | Generator Loss: 166.9785 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [360/1000] | Generator Loss: 167.1594 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9072 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Epoch [361/1000] | Generator Loss: 167.1633 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [362/1000] | Generator Loss: 167.1687 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [363/1000] | Generator Loss: 166.9383 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [364/1000] | Generator Loss: 166.8873 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [365/1000] | Generator Loss: 166.7048 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0002
# Epoch [366/1000] | Generator Loss: 166.5123 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [367/1000] | Generator Loss: 166.4883 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [368/1000] | Generator Loss: 166.5586 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [369/1000] | Generator Loss: 166.6657 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [370/1000] | Generator Loss: 166.5374 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.8959 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [371/1000] | Generator Loss: 166.4908 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [372/1000] | Generator Loss: 166.3003 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [373/1000] | Generator Loss: 166.4969 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [374/1000] | Generator Loss: 166.6401 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0005
# Epoch [375/1000] | Generator Loss: 166.4032 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [376/1000] | Generator Loss: 166.2695 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [377/1000] | Generator Loss: 166.1499 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0154
# Epoch [378/1000] | Generator Loss: 166.2991 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0003
# Epoch [379/1000] | Generator Loss: 166.0326 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [380/1000] | Generator Loss: 165.6996 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0005
# Validation | Generator Loss: 0.8853 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0111
# Epoch [381/1000] | Generator Loss: 165.8073 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0006
# Epoch [382/1000] | Generator Loss: 166.0686 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [383/1000] | Generator Loss: 166.1770 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [384/1000] | Generator Loss: 166.1313 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [385/1000] | Generator Loss: 166.0737 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [386/1000] | Generator Loss: 165.9247 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [387/1000] | Generator Loss: 166.0133 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [388/1000] | Generator Loss: 165.9667 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [389/1000] | Generator Loss: 165.7709 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [390/1000] | Generator Loss: 165.8120 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9190 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [391/1000] | Generator Loss: 165.5507 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [392/1000] | Generator Loss: 165.7422 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [393/1000] | Generator Loss: 165.6481 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [394/1000] | Generator Loss: 165.6097 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [395/1000] | Generator Loss: 165.4049 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [396/1000] | Generator Loss: 165.5209 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [397/1000] | Generator Loss: 165.8029 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [398/1000] | Generator Loss: 165.6906 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [399/1000] | Generator Loss: 165.5972 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [400/1000] | Generator Loss: 165.2571 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 0.8947 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [401/1000] | Generator Loss: 165.1915 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [402/1000] | Generator Loss: 165.1246 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [403/1000] | Generator Loss: 165.1728 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [404/1000] | Generator Loss: 165.0816 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [405/1000] | Generator Loss: 164.8998 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [406/1000] | Generator Loss: 165.0208 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [407/1000] | Generator Loss: 165.0758 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [408/1000] | Generator Loss: 164.8809 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [409/1000] | Generator Loss: 164.6790 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [410/1000] | Generator Loss: 164.9104 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9153 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [411/1000] | Generator Loss: 164.9659 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [412/1000] | Generator Loss: 164.8818 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [413/1000] | Generator Loss: 164.6899 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [414/1000] | Generator Loss: 164.9062 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0004
# Epoch [415/1000] | Generator Loss: 164.9420 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [416/1000] | Generator Loss: 164.7332 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [417/1000] | Generator Loss: 164.7694 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0004
# Epoch [418/1000] | Generator Loss: 164.8602 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# ...
# Epoch [482/1000] | Generator Loss: 163.6533 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [483/1000] | Generator Loss: 163.8082 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [484/1000] | Generator Loss: 163.9588 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [485/1000] | Generator Loss: 163.5925 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [486/1000] | Generator Loss: 163.8059 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [487/1000] | Generator Loss: 163.7994 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [488/1000] | Generator Loss: 163.6685 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0001
# Epoch [489/1000] | Generator Loss: 163.8052 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0041
# Epoch [490/1000] | Generator Loss: 163.5029 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.8501 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0005
# Epoch [491/1000] | Generator Loss: 163.4556 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [492/1000] | Generator Loss: 163.8319 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [493/1000] | Generator Loss: 163.5234 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [494/1000] | Generator Loss: 163.5181 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [495/1000] | Generator Loss: 163.3862 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [496/1000] | Generator Loss: 163.7805 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0001
# Epoch [497/1000] | Generator Loss: 163.5419 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [498/1000] | Generator Loss: 163.5949 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0000
# Epoch [499/1000] | Generator Loss: 163.3635 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0000
# Epoch [500/1000] | Generator Loss: 163.5347 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 0.9513 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0006
# Epoch [501/1000] | Generator Loss: 163.3443 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [502/1000] | Generator Loss: 163.0649 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [503/1000] | Generator Loss: 163.1844 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [504/1000] | Generator Loss: 163.6505 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0010
# Epoch [505/1000] | Generator Loss: 163.4406 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [506/1000] | Generator Loss: 163.2585 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [507/1000] | Generator Loss: 163.0812 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [508/1000] | Generator Loss: 163.0334 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [509/1000] | Generator Loss: 163.1190 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [510/1000] | Generator Loss: 162.9627 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.9155 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [511/1000] | Generator Loss: 162.7347 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [512/1000] | Generator Loss: 162.8415 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [513/1000] | Generator Loss: 162.6983 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0001
# Epoch [514/1000] | Generator Loss: 162.8362 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [515/1000] | Generator Loss: 162.4524 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [516/1000] | Generator Loss: 162.3989 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [517/1000] | Generator Loss: 162.5181 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [518/1000] | Generator Loss: 162.6615 | Discriminator S Loss: 0.0003 | Discriminator H Loss: 0.0000
# Epoch [519/1000] | Generator Loss: 162.5167 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [520/1000] | Generator Loss: 162.5213 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.8835 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0000
# Epoch [521/1000] | Generator Loss: 162.5059 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [522/1000] | Generator Loss: 162.4614 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [523/1000] | Generator Loss: 162.7629 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0008
# Epoch [524/1000] | Generator Loss: 162.5863 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [525/1000] | Generator Loss: 162.7242 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [526/1000] | Generator Loss: 162.4877 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [527/1000] | Generator Loss: 162.4256 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [528/1000] | Generator Loss: 162.5066 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0000
# Epoch [529/1000] | Generator Loss: 162.4239 | Discriminator S Loss: 0.0008 | Discriminator H Loss: 0.0001
# Epoch [530/1000] | Generator Loss: 162.2821 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.8835 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [531/1000] | Generator Loss: 161.6404 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [532/1000] | Generator Loss: 161.6066 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0002
# Epoch [533/1000] | Generator Loss: 161.8323 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [534/1000] | Generator Loss: 161.6823 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [535/1000] | Generator Loss: 161.7027 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [536/1000] | Generator Loss: 161.8563 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0003
# Epoch [537/1000] | Generator Loss: 161.6480 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [538/1000] | Generator Loss: 161.7506 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [539/1000] | Generator Loss: 161.7049 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [540/1000] | Generator Loss: 161.6866 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.9039 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [541/1000] | Generator Loss: 161.4747 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [542/1000] | Generator Loss: 161.6563 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [543/1000] | Generator Loss: 161.8842 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [544/1000] | Generator Loss: 161.6209 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [545/1000] | Generator Loss: 161.6909 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [546/1000] | Generator Loss: 161.7544 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [547/1000] | Generator Loss: 161.7979 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [548/1000] | Generator Loss: 161.5912 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [549/1000] | Generator Loss: 161.3674 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [550/1000] | Generator Loss: 161.4083 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.8802 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [551/1000] | Generator Loss: 160.9596 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [552/1000] | Generator Loss: 161.3381 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [553/1000] | Generator Loss: 160.8763 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [554/1000] | Generator Loss: 160.9055 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [555/1000] | Generator Loss: 160.7115 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [556/1000] | Generator Loss: 160.3513 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0003
# Epoch [557/1000] | Generator Loss: 160.7418 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [558/1000] | Generator Loss: 160.2226 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [559/1000] | Generator Loss: 160.3988 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [560/1000] | Generator Loss: 160.6445 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.9047 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [561/1000] | Generator Loss: 160.3361 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [562/1000] | Generator Loss: 160.1006 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [563/1000] | Generator Loss: 160.1080 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [564/1000] | Generator Loss: 160.1364 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [565/1000] | Generator Loss: 159.8772 | Discriminator S Loss: 0.0006 | Discriminator H Loss: 0.0001
# Epoch [566/1000] | Generator Loss: 159.7771 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [567/1000] | Generator Loss: 159.8171 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [568/1000] | Generator Loss: 159.6441 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [569/1000] | Generator Loss: 159.7487 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [570/1000] | Generator Loss: 159.7921 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.8847 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [571/1000] | Generator Loss: 159.4737 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [572/1000] | Generator Loss: 159.5011 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [573/1000] | Generator Loss: 159.6355 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0014
# Epoch [574/1000] | Generator Loss: 159.4834 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [575/1000] | Generator Loss: 159.7074 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Epoch [576/1000] | Generator Loss: 159.6165 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [577/1000] | Generator Loss: 159.7268 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0001
# Epoch [578/1000] | Generator Loss: 159.7418 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [579/1000] | Generator Loss: 159.6581 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [580/1000] | Generator Loss: 159.9344 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Validation | Generator Loss: 0.8947 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [581/1000] | Generator Loss: 160.1581 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [582/1000] | Generator Loss: 160.1339 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [583/1000] | Generator Loss: 160.1204 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0004
# Epoch [584/1000] | Generator Loss: 159.9870 | Discriminator S Loss: 0.0004 | Discriminator H Loss: 0.0001
# Epoch [585/1000] | Generator Loss: 160.0131 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [586/1000] | Generator Loss: 159.9020 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [587/1000] | Generator Loss: 159.9413 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [588/1000] | Generator Loss: 159.6515 | Discriminator S Loss: 0.0007 | Discriminator H Loss: 0.0001
# Epoch [589/1000] | Generator Loss: 159.7415 | Discriminator S Loss: 0.0005 | Discriminator H Loss: 0.0001
# Epoch [590/1000] | Generator Loss: 159.8441 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Validation | Generator Loss: 0.9217 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [591/1000] | Generator Loss: 159.9680 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [592/1000] | Generator Loss: 159.8805 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [593/1000] | Generator Loss: 159.9041 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0007
# Epoch [594/1000] | Generator Loss: 160.0476 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0001
# Epoch [595/1000] | Generator Loss: 159.5050 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [596/1000] | Generator Loss: 159.3636 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0004
# Epoch [597/1000] | Generator Loss: 159.2838 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [598/1000] | Generator Loss: 158.5513 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [599/1000] | Generator Loss: 159.0504 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [600/1000] | Generator Loss: 159.0288 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.8718 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [601/1000] | Generator Loss: 159.0425 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0000
# Epoch [602/1000] | Generator Loss: 159.0611 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [603/1000] | Generator Loss: 159.1753 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [604/1000] | Generator Loss: 159.0775 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [605/1000] | Generator Loss: 159.2809 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [606/1000] | Generator Loss: 159.2608 | Discriminator S Loss: 0.0002 | Discriminator H Loss: 0.0000
# Epoch [607/1000] | Generator Loss: 159.1585 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [608/1000] | Generator Loss: 159.2887 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [609/1000] | Generator Loss: 159.4494 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [610/1000] | Generator Loss: 159.2437 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Validation | Generator Loss: 0.8827 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [611/1000] | Generator Loss: 159.3182 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [612/1000] | Generator Loss: 159.3368 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0001
# Epoch [613/1000] | Generator Loss: 159.1187 | Discriminator S Loss: 0.0001 | Discriminator H Loss: 0.0002
# Epoch [614/1000] | Generator Loss: 159.4963 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0002
# Epoch [615/1000] | Generator Loss: 159.4787 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [616/1000] | Generator Loss: 159.4680 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0001
# Epoch [617/1000] | Generator Loss: 159.6145 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0007
# Epoch [618/1000] | Generator Loss: 159.6224 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000
# Epoch [619/1000] | Generator Loss: 159.9709 | Discriminator S Loss: 0.0000 | Discriminator H Loss: 0.0000

# %%
def reconstruct_hidden_image(generator_S2H, stego_img):
    device = 'cuda'
       
    reconstructed_hidden_image = generator_S2H(stego_img.to(device)).detach()
    
    return reconstructed_hidden_image.cpu()

def load_saved_dicts(generator_H2S, generator_S2H, discriminator_S, discriminator_H, optimizer_G, optimizer_S, optimizer_H, flag):
    generator_H2S.load_state_dict(torch.load(f'./model_params/PVD/H2S/generator_H2S_epoch_{flag}.pth'))
    generator_S2H.load_state_dict(torch.load(f'./model_params/PVD/S2H/generator_S2H_epoch_{flag}.pth'))
    discriminator_S.load_state_dict(torch.load(f'./model_params/PVD/DS/discriminator_S_epoch_{flag}.pth'))
    discriminator_H.load_state_dict(torch.load(f'./model_params/PVD/DH/discriminator_H_epoch_{flag}.pth'))
    
    optimizer_G.load_state_dict(torch.load(f'./model_params/PVD/optimizer/G/optimizer_G_{flag}.pth'))
    optimizer_S.load_state_dict(torch.load(f'./model_params/PVD/optimizer/S/optimizer_S_{flag}.pth'))
    optimizer_H.load_state_dict(torch.load(f'./model_params/PVD/optimizer/H/optimizer_H_{flag}.pth'))

# %%
def reconstruct_hidden_images(generator_H2S, generator_S2H, test_cover_loader, test_stego_loader, output_dir, flag):
    to_pil_image = transforms.ToPILImage()
    
    for i, (cover_data, stego_data) in enumerate(zip(test_cover_loader, test_stego_loader)):
        cover_image_tensor, _ = cover_data
        stego_image_tensor, _ = stego_data
        
        # Move tensors to the appropriate device
        device = torch.device("cuda")
        cover_image_tensor = cover_image_tensor.to(device)
        stego_image_tensor = stego_image_tensor.to(device)
        
        # Reconstruct the hidden image
        reconstructed_hidden_image = reconstruct_hidden_image(generator_S2H, stego_image_tensor)
        
        # Convert the reconstructed hidden image back to a PIL Image
        reconstructed_hidden_image_pil = to_pil_image(reconstructed_hidden_image.squeeze(0))
        
        # Save the reconstructed hidden image
        output_path = os.path.join(output_dir, f"{flag}/{i}.png")
        reconstructed_hidden_image_pil.save(output_path)

# %%
def change_lr(optimizer_G, optimizer_H, optimizer_S, flag):
    
    optimizer_G_state_dict = torch.load(f'./model_params/PVD/optimizer/G/optimizer_G_{flag}.pth')
    optimizer_H_state_dict = torch.load(f'./model_params/PVD/optimizer/H/optimizer_H_{flag}.pth')
    optimizer_S_state_dict = torch.load(f'./model_params/PVD/optimizer/S/optimizer_S_{flag}.pth')
    
    optimizer_G_state_dict['param_groups'][0]['lr'] = 0.001
    optimizer_H_state_dict['param_groups'][0]['lr'] = 0.00001
    optimizer_S_state_dict['param_groups'][0]['lr'] = 0.00001

    optimizer_G.load_state_dict(optimizer_G_state_dict)
    optimizer_H.load_state_dict(optimizer_H_state_dict)
    optimizer_S.load_state_dict(optimizer_S_state_dict)

# %%
# reconstruct
flag = 500
output_dir = './reconstructed_hidden/PVD/'

load_saved_dicts(generator_H2S, generator_S2H, discriminator_S, discriminator_H, optimizer_G, optimizer_S, optimizer_H, flag=flag)

# change lr at epoch 1000
# change_lr(optimizer_G, optimizer_C, optimizer_S, flag=flag)

flag = 500
# reconstruct at epoch flag
reconstruct_hidden_images(generator_H2S, generator_S2H, test_cover_loader, test_stego_loader, output_dir, flag)
