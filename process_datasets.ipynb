# %%
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim
from typing import List
import generate_pictures


def compare_images(imageA: np.ndarray, imageB: np.ndarray) -> float:
    win_size = min(imageA.shape[0], imageA.shape[1], imageB.shape[0], imageB.shape[1])
    win_size = max(win_size, 1)
    if win_size % 2 == 0:
        win_size -= 1
    return ssim(imageA, imageB, win_size=win_size, multichannel=True, channel_axis=2)

def optimized_pairing(group_a: List[str], group_b: List[str]) -> List[str]:
    # Sort both groups in ascending order
    group_a.sort()
    group_b.sort()

    paired_group_b = [None] * len(group_b)
    used_indices = set()

    # Iterate through the sorted groups to find optimal pairs
    for a in group_a:
        max_compare_value = -2
        max_index = -1

        for i, b in enumerate(group_b):
            if i not in used_indices:
                a_img = cv2.imread(a)
                b_img = cv2.imread(b)
                compare_value = compare_images(a_img, b_img)

                if compare_value > max_compare_value:
                    max_compare_value = compare_value
                    max_index = i
        print('Max_compare_value: ',max_compare_value, 'at idx', str(max_index))
        used_indices.add(max_index)
        paired_group_b[group_a.index(a)] = group_b[max_index]
        print('Image', str(a), 'Max: ', max_compare_value)
    return paired_group_b

def process_images(group1: List[str], group2: List[str], output_dir: str) -> None:
    group2_reordered = optimized_pairing(group1, group2)

    for cover_image_path, secret_image_path in zip(group1, group2_reordered):
        encoded_image_name = os.path.basename(cover_image_path)
        encoded_image_path = os.path.join(output_dir, encoded_image_name)
        generate_pictures.pvd_encode_rgb(cover_image_path, secret_image_path, encoded_image_path)

if __name__ == "__main__":
    image_directory = 'filtered_1'
    encoded_image_directory = 'final_2'

    image_paths = [
        os.path.join(image_directory, f) for f in os.listdir(image_directory) if f.endswith((".jpg", ".jpeg", ".png"))
    ]
    image_paths.sort()  # Make sure the list is sorted
    image_paths = image_paths[:422]  # Select the first 422 images

    # Remove duplicates
    image_paths = list(set(image_paths))

    group1 = image_paths[:len(image_paths)//2]
    group2 = image_paths[len(image_paths)//2:]

    process_images(group1, group2, encoded_image_directory)
# Out:
# Max_compare_value:  0.54731096954784 at idx 93
# Image filtered_1\00000003_(4).jpg Max:  0.54731096954784
# Max_compare_value:  0.7671149059396982 at idx 119
# Image filtered_1\00000007_(4).jpg Max:  0.7671149059396982
# Max_compare_value:  0.6260021562596204 at idx 204
# Image filtered_1\00000012_(6).jpg Max:  0.6260021562596204
# Max_compare_value:  0.8612034549633111 at idx 124
# Image filtered_1\00000016_(3).jpg Max:  0.8612034549633111
# Max_compare_value:  0.7737916561664312 at idx 7
# Image filtered_1\00000017_(6).jpg Max:  0.7737916561664312
# Max_compare_value:  0.8503010265901066 at idx 88
# Image filtered_1\00000032_(6).jpg Max:  0.8503010265901066
# Max_compare_value:  0.7275648170332504 at idx 40
# Image filtered_1\00000045_(2).jpg Max:  0.7275648170332504
# Max_compare_value:  0.41588477331912 at idx 18
# Image filtered_1\00000050_(5).jpg Max:  0.41588477331912
# Max_compare_value:  0.7195752687107045 at idx 29
# Image filtered_1\00000062_(6).jpg Max:  0.7195752687107045
# Max_compare_value:  0.996597480606605 at idx 14
# Image filtered_1\00000063_(6).jpg Max:  0.996597480606605
# Max_compare_value:  0.8121268895246976 at idx 92
# Image filtered_1\00000078_(5).jpg Max:  0.8121268895246976
# Max_compare_value:  0.5224599026990235 at idx 27
# Image filtered_1\00000083_(4).jpg Max:  0.5224599026990235
# Max_compare_value:  0.46680433317448605 at idx 131
# Image filtered_1\00000086_(5).jpg Max:  0.46680433317448605
# Max_compare_value:  0.813224596128553 at idx 149
# Image filtered_1\00000089_(3).jpg Max:  0.813224596128553
# Max_compare_value:  0.6959222257732905 at idx 5
# Image filtered_1\00000099_(6).jpg Max:  0.6959222257732905
# Max_compare_value:  1.0 at idx 22
# Image filtered_1\00000101_(7).jpg Max:  1.0
# Max_compare_value:  0.39151099767010816 at idx 175
# Image filtered_1\00000104_(2).jpg Max:  0.39151099767010816
# Max_compare_value:  0.9987732980973997 at idx 25
# Image filtered_1\00000111_(6).jpg Max:  0.9987732980973997
# Max_compare_value:  0.8628248740985329 at idx 97
# Image filtered_1\00000112_(2).jpg Max:  0.8628248740985329
# Max_compare_value:  0.6221917310124062 at idx 66
# Image filtered_1\00000118_(3).jpg Max:  0.6221917310124062
# Max_compare_value:  0.6697634377663334 at idx 179
# Image filtered_1\00000118_(6).jpg Max:  0.6697634377663334
# Max_compare_value:  0.9969532057708005 at idx 28
# Image filtered_1\00000123_(6).jpg Max:  0.9969532057708005
# Max_compare_value:  0.42862946266692087 at idx 13
# Image filtered_1\00000124_(2).jpg Max:  0.42862946266692087
# Max_compare_value:  0.37209780686066146 at idx 32
# Image filtered_1\00000124_(4).jpg Max:  0.37209780686066146
# Max_compare_value:  0.6939947242461604 at idx 37
# Image filtered_1\00000142_(6).jpg Max:  0.6939947242461604
# Max_compare_value:  0.7128272688231144 at idx 181
# Image filtered_1\00000153_(4).jpg Max:  0.7128272688231144
# Max_compare_value:  0.7533597641761629 at idx 161
# Image filtered_1\00000157_(4).jpg Max:  0.7533597641761629
# Max_compare_value:  0.7213403938422879 at idx 98
# Image filtered_1\00000158_(2).jpg Max:  0.7213403938422879
# Max_compare_value:  0.32645365281613903 at idx 79
# Image filtered_1\00000159_(4).jpg Max:  0.32645365281613903
# Max_compare_value:  0.7378557300267182 at idx 173
# Image filtered_1\00000171_(5).jpg Max:  0.7378557300267182
# Max_compare_value:  0.18852844939224442 at idx 193
# Image filtered_1\00000175_(5).jpg Max:  0.18852844939224442
# Max_compare_value:  0.5829552583020915 at idx 34
# Image filtered_1\00000175_(6).jpg Max:  0.5829552583020915
# Max_compare_value:  0.5794750873518668 at idx 122
# Image filtered_1\00000176_(6).jpg Max:  0.5794750873518668
# Max_compare_value:  0.265149095030585 at idx 16
# Image filtered_1\00000180_(2).jpg Max:  0.265149095030585
# Max_compare_value:  0.4756658559989965 at idx 133
# Image filtered_1\00000189_(6).jpg Max:  0.4756658559989965
# Max_compare_value:  0.5045944092671626 at idx 188
# Image filtered_1\00000191_(4).jpg Max:  0.5045944092671626
# Max_compare_value:  0.4053368497741301 at idx 26
# Image filtered_1\00000192_(2).jpg Max:  0.4053368497741301
# Max_compare_value:  0.7431959740585158 at idx 61
# Image filtered_1\00000198_(6).jpg Max:  0.7431959740585158
# Max_compare_value:  0.4730578752162726 at idx 152
# Image filtered_1\00000207_(3).jpg Max:  0.4730578752162726
# Max_compare_value:  0.42217242188501913 at idx 154
# Image filtered_1\00000208_(2).jpg Max:  0.42217242188501913
# Max_compare_value:  0.47244454684732906 at idx 81
# Image filtered_1\00000217_(4).jpg Max:  0.47244454684732906
# Max_compare_value:  0.4848629528287873 at idx 186
# Image filtered_1\00000221_(3).jpg Max:  0.4848629528287873
# Max_compare_value:  0.6482920573463908 at idx 137
# Image filtered_1\00000222_(4).jpg Max:  0.6482920573463908
# Max_compare_value:  0.5497491388337602 at idx 111
# Image filtered_1\00000223_(5).jpg Max:  0.5497491388337602
# Max_compare_value:  0.1345342442347427 at idx 33
# Image filtered_1\00000225_(6).jpg Max:  0.1345342442347427
# Max_compare_value:  0.5643326773045111 at idx 78
# Image filtered_1\00000236_(6).jpg Max:  0.5643326773045111
# Max_compare_value:  0.4511013270869877 at idx 6
# Image filtered_1\00000241_(6).jpg Max:  0.4511013270869877
# Max_compare_value:  0.2737129490488188 at idx 136
# Image filtered_1\00000243_(4).jpg Max:  0.2737129490488188
# Max_compare_value:  1.0 at idx 67
# Image filtered_1\00000243_(6).jpg Max:  1.0
# Max_compare_value:  0.47633133902123975 at idx 192
# Image filtered_1\00000249_(5).jpg Max:  0.47633133902123975
# Max_compare_value:  0.6032071323936967 at idx 58
# Image filtered_1\00000251.jpg Max:  0.6032071323936967
# Max_compare_value:  0.4283897880678609 at idx 129
# Image filtered_1\00000255_(4).jpg Max:  0.4283897880678609
# Max_compare_value:  0.29844504528183186 at idx 189
# Image filtered_1\00000255_(6).jpg Max:  0.29844504528183186
# Max_compare_value:  0.4245128595586342 at idx 191
# Image filtered_1\00000260_(4).jpg Max:  0.4245128595586342
# Max_compare_value:  0.4490210627012816 at idx 115
# Image filtered_1\00000262_(2).jpg Max:  0.4490210627012816
# Max_compare_value:  0.614323403724384 at idx 201
# Image filtered_1\00000262_(5).jpg Max:  0.614323403724384
# Max_compare_value:  1.0 at idx 69
# Image filtered_1\00000271_(6).jpg Max:  1.0
# Max_compare_value:  0.7832829484735093 at idx 45
# Image filtered_1\00000278_(6).jpg Max:  0.7832829484735093
# Max_compare_value:  0.7914635686530899 at idx 50
# Image filtered_1\00000279_(3).jpg Max:  0.7914635686530899
# Max_compare_value:  0.26103253553897837 at idx 132
# Image filtered_1\00000279_(4).jpg Max:  0.26103253553897837
# Max_compare_value:  0.9995217008772569 at idx 74
# Image filtered_1\00000280_(6).jpg Max:  0.9995217008772569
# Max_compare_value:  0.7033681751678013 at idx 160
# Image filtered_1\00000282.jpg Max:  0.7033681751678013
# Max_compare_value:  0.517179558794116 at idx 43
# Image filtered_1\00000282_(3).jpg Max:  0.517179558794116
# Max_compare_value:  0.999663080142955 at idx 73
# Image filtered_1\00000290_(6).jpg Max:  0.999663080142955
# Max_compare_value:  0.6935602585165502 at idx 86
# Image filtered_1\00000292_(5).jpg Max:  0.6935602585165502
# Max_compare_value:  0.34862269397407347 at idx 209
# Image filtered_1\00000293_(2).jpg Max:  0.34862269397407347
# Max_compare_value:  0.7077915532942393 at idx 205
# Image filtered_1\00000300.jpg Max:  0.7077915532942393
# Max_compare_value:  0.582188976170213 at idx 183
# Image filtered_1\00000306_(3).jpg Max:  0.582188976170213
# Max_compare_value:  0.7706862628734114 at idx 65
# Image filtered_1\00000307_(3).jpg Max:  0.7706862628734114
# Max_compare_value:  0.331469366293472 at idx 117
# Image filtered_1\00000310_(4).jpg Max:  0.331469366293472
# Max_compare_value:  0.4818128662839349 at idx 99
# Image filtered_1\00000310_(5).jpg Max:  0.4818128662839349
# Max_compare_value:  0.9995238384630509 at idx 103
# Image filtered_1\00000310_(6).jpg Max:  0.9995238384630509
# Max_compare_value:  0.7461651014464267 at idx 68
# Image filtered_1\00000311_(6).jpg Max:  0.7461651014464267
# Max_compare_value:  0.41901224475073207 at idx 112
# Image filtered_1\00000315_(4).jpg Max:  0.41901224475073207
# Max_compare_value:  0.36513639656274877 at idx 63
# Image filtered_1\00000316_(5).jpg Max:  0.36513639656274877
# Max_compare_value:  0.46636681458098633 at idx 19
# Image filtered_1\00000318_(4).jpg Max:  0.46636681458098633
# Max_compare_value:  0.3997062418181913 at idx 24
# Image filtered_1\00000320_(4).jpg Max:  0.3997062418181913
# Max_compare_value:  0.8416978605210105 at idx 52
# Image filtered_1\00000321_(2).jpg Max:  0.8416978605210105
# Max_compare_value:  0.25542496879026233 at idx 169
# Image filtered_1\00000327_(6).jpg Max:  0.25542496879026233
# Max_compare_value:  0.37337924086954805 at idx 59
# Image filtered_1\00000330_(4).jpg Max:  0.37337924086954805
# Max_compare_value:  0.8880720677466435 at idx 140
# Image filtered_1\00000331_(6).jpg Max:  0.8880720677466435
# Max_compare_value:  0.7672619085578459 at idx 56
# Image filtered_1\00000335_(2).jpg Max:  0.7672619085578459
# Max_compare_value:  0.8521003503363955 at idx 176
# Image filtered_1\00000337_(6).jpg Max:  0.8521003503363955
# Max_compare_value:  0.9995442160836795 at idx 82
# Image filtered_1\00000339_(6).jpg Max:  0.9995442160836795
# Max_compare_value:  0.4687265040590698 at idx 41
# Image filtered_1\00000340_(6).jpg Max:  0.4687265040590698
# Max_compare_value:  0.8871028771071559 at idx 159
# Image filtered_1\00000341_(6).jpg Max:  0.8871028771071559
# Max_compare_value:  0.8429696845714828 at idx 208
# Image filtered_1\00000342_(5).jpg Max:  0.8429696845714828
# Max_compare_value:  0.9547933678111468 at idx 138
# Image filtered_1\00000342_(6).jpg Max:  0.9547933678111468
# Max_compare_value:  0.7287809632557473 at idx 87
# Image filtered_1\00000347_(6).jpg Max:  0.7287809632557473
# Max_compare_value:  0.4151206589150114 at idx 118
# Image filtered_1\00000349_(3).jpg Max:  0.4151206589150114
# Max_compare_value:  0.9996334740136289 at idx 91
# Image filtered_1\00000350_(6).jpg Max:  0.9996334740136289
# Max_compare_value:  0.3509381929753322 at idx 202
# Image filtered_1\00000353_(5).jpg Max:  0.3509381929753322
# Max_compare_value:  0.2579093261111109 at idx 51
# Image filtered_1\00000353_(6).jpg Max:  0.2579093261111109
# Max_compare_value:  0.47081826145417566 at idx 199
# Image filtered_1\00000356_(4).jpg Max:  0.47081826145417566
# Max_compare_value:  0.7053290668759101 at idx 121
# Image filtered_1\00000356_(6).jpg Max:  0.7053290668759101
# Max_compare_value:  0.5223887631349872 at idx 70
# Image filtered_1\00000359_(2).jpg Max:  0.5223887631349872
# Max_compare_value:  0.2393243423305124 at idx 36
# Image filtered_1\00000360_(6).jpg Max:  0.2393243423305124
# Max_compare_value:  0.7471919045607022 at idx 94
# Image filtered_1\00000362_(5).jpg Max:  0.7471919045607022
# Max_compare_value:  0.9655229936137855 at idx 110
# Image filtered_1\00000362_(6).jpg Max:  0.9655229936137855
# Max_compare_value:  1.0 at idx 106
# Image filtered_1\00000363_(6).jpg Max:  1.0
# Max_compare_value:  0.22753202250811522 at idx 71
# Image filtered_1\00000364_(4).jpg Max:  0.22753202250811522
# Max_compare_value:  1.0 at idx 104
# Image filtered_1\00000367_(6).jpg Max:  1.0
# Max_compare_value:  0.9655229936137855 at idx 134
# Image filtered_1\00000370_(6).jpg Max:  0.9655229936137855
# Max_compare_value:  0.8276138850342295 at idx 150
# Image filtered_1\00000376_(6).jpg Max:  0.8276138850342295
# Max_compare_value:  0.7797373030098265 at idx 166
# Image filtered_1\00000381_(6).jpg Max:  0.7797373030098265
# Max_compare_value:  0.174082314366199 at idx 105
# Image filtered_1\00000383_(5).jpg Max:  0.174082314366199
# Max_compare_value:  0.7538942356125787 at idx 23
# Image filtered_1\00000386_(6).jpg Max:  0.7538942356125787
# Max_compare_value:  0.19568399927414457 at idx 49
# Image filtered_1\00000389_(3).jpg Max:  0.19568399927414457
# Max_compare_value:  0.5559606629871628 at idx 72
# Image filtered_1\00000391_(3).jpg Max:  0.5559606629871628
# Max_compare_value:  0.5385185926975811 at idx 46
# Image filtered_1\00000393_(5).jpg Max:  0.5385185926975811
# Max_compare_value:  0.2694269109192862 at idx 75
# Image filtered_1\00000402_(3).jpg Max:  0.2694269109192862
# Max_compare_value:  0.5327539756851457 at idx 203
# Image filtered_1\00000402_(5).jpg Max:  0.5327539756851457
# Max_compare_value:  0.7021070773535065 at idx 114
# Image filtered_1\00000403_(2).jpg Max:  0.7021070773535065
# Max_compare_value:  0.3025350282947595 at idx 120
# Image filtered_1\00000409_(2).jpg Max:  0.3025350282947595
# Max_compare_value:  0.7239915703230655 at idx 2
# Image filtered_1\00000409_(5).jpg Max:  0.7239915703230655
# Max_compare_value:  0.7846359353683025 at idx 170
# Image filtered_1\00000420_(5).jpg Max:  0.7846359353683025
# Max_compare_value:  0.648124872468559 at idx 185
# Image filtered_1\00000423_(3).jpg Max:  0.648124872468559
# Max_compare_value:  0.43990963378694525 at idx 195
# Image filtered_1\00000427_(5).jpg Max:  0.43990963378694525
# Max_compare_value:  0.5157895713304051 at idx 180
# Image filtered_1\00000439_(4).jpg Max:  0.5157895713304051
# Max_compare_value:  0.9965832714623147 at idx 130
# Image filtered_1\00000439_(5).jpg Max:  0.9965832714623147
# Max_compare_value:  0.7442145074232206 at idx 90
# Image filtered_1\00000441_(5).jpg Max:  0.7442145074232206
# Max_compare_value:  0.5332386510001091 at idx 145
# Image filtered_1\00000446_(2).jpg Max:  0.5332386510001091
# Max_compare_value:  0.2643549148188221 at idx 84
# Image filtered_1\00000446_(4).jpg Max:  0.2643549148188221
# Max_compare_value:  0.4539152470602577 at idx 42
# Image filtered_1\00000448_(4).jpg Max:  0.4539152470602577
# Max_compare_value:  1.0 at idx 135
# Image filtered_1\00000455_(5).jpg Max:  1.0
# Max_compare_value:  0.7073569189187031 at idx 60
# Image filtered_1\00000460_(5).jpg Max:  0.7073569189187031
# Max_compare_value:  0.7963630023453009 at idx 164
# Image filtered_1\00000462_(5).jpg Max:  0.7963630023453009
# Max_compare_value:  0.5527283997875919 at idx 57
# Image filtered_1\00000463_(3).jpg Max:  0.5527283997875919
# Max_compare_value:  0.6732339146145428 at idx 190
# Image filtered_1\00000463_(5).jpg Max:  0.6732339146145428
# Max_compare_value:  0.6004492268821339 at idx 0
# Image filtered_1\00000464_(5).jpg Max:  0.6004492268821339
# Max_compare_value:  0.5846168346310101 at idx 172
# Image filtered_1\00000468_(5).jpg Max:  0.5846168346310101
# Max_compare_value:  0.6830339441365824 at idx 95
# Image filtered_1\00000474_(4).jpg Max:  0.6830339441365824
# Max_compare_value:  0.5731560729982671 at idx 89
# Image filtered_1\00000475_(3).jpg Max:  0.5731560729982671
# Max_compare_value:  0.59677741307806 at idx 167
# Image filtered_1\00000476_(5).jpg Max:  0.59677741307806
# Max_compare_value:  0.6261011816256832 at idx 48
# Image filtered_1\00000478_(5).jpg Max:  0.6261011816256832
# Max_compare_value:  0.6349564804041031 at idx 147
# Image filtered_1\00000479_(5).jpg Max:  0.6349564804041031
# Max_compare_value:  0.6767096808405237 at idx 107
# Image filtered_1\00000481_(5).jpg Max:  0.6767096808405237
# Max_compare_value:  0.6458370444359679 at idx 96
# Image filtered_1\00000482_(5).jpg Max:  0.6458370444359679
# Max_compare_value:  0.3447530014485261 at idx 187
# Image filtered_1\00000484_(2).jpg Max:  0.3447530014485261
# Max_compare_value:  0.5324639957880668 at idx 206
# Image filtered_1\00000485_(5).jpg Max:  0.5324639957880668
# Max_compare_value:  0.5422489101646101 at idx 12
# Image filtered_1\00000489_(4).jpg Max:  0.5422489101646101
# Max_compare_value:  0.559828923318697 at idx 3
# Image filtered_1\00000490_(2).jpg Max:  0.559828923318697
# Max_compare_value:  0.5197172940543202 at idx 182
# Image filtered_1\00000491.jpg Max:  0.5197172940543202
# Max_compare_value:  0.768625035982839 at idx 102
# Image filtered_1\00000491_(5).jpg Max:  0.768625035982839
# Max_compare_value:  0.623903575307947 at idx 210
# Image filtered_1\00000492_(5).jpg Max:  0.623903575307947
# Max_compare_value:  0.15060542591510706 at idx 15
# Image filtered_1\00000493_(4).jpg Max:  0.15060542591510706
# Max_compare_value:  0.3106557265851361 at idx 39
# Image filtered_1\00000493_(5).jpg Max:  0.3106557265851361
# Max_compare_value:  0.5661787290070243 at idx 177
# Image filtered_1\00000495.jpg Max:  0.5661787290070243
# Max_compare_value:  0.5331626673274218 at idx 109
# Image filtered_1\00000496_(5).jpg Max:  0.5331626673274218
# Max_compare_value:  0.29572741153254495 at idx 142
# Image filtered_1\00000507_(5).jpg Max:  0.29572741153254495
# Max_compare_value:  0.2604300997133157 at idx 143
# Image filtered_1\00000518_(5).jpg Max:  0.2604300997133157
# Max_compare_value:  0.4029759950320382 at idx 44
# Image filtered_1\00000519_(5).jpg Max:  0.4029759950320382
# Max_compare_value:  0.33698923480258075 at idx 62
# Image filtered_1\00000520_(5).jpg Max:  0.33698923480258075
# Max_compare_value:  0.4398911280253297 at idx 8
# Image filtered_1\00000521_(3).jpg Max:  0.4398911280253297
# Max_compare_value:  0.5527715308434753 at idx 163
# Image filtered_1\00000522_(3).jpg Max:  0.5527715308434753
# Max_compare_value:  0.1804158894536604 at idx 198
# Image filtered_1\00000525.jpg Max:  0.1804158894536604
# Max_compare_value:  0.611156694379884 at idx 165
# Image filtered_1\00000527_(5).jpg Max:  0.611156694379884
# Max_compare_value:  0.5444786606505957 at idx 157
# Image filtered_1\00000536_(5).jpg Max:  0.5444786606505957
# Max_compare_value:  0.20905861724862443 at idx 156
# Image filtered_1\00000538_(2).jpg Max:  0.20905861724862443
# Max_compare_value:  0.4072131592320322 at idx 207
# Image filtered_1\00000549_(3).jpg Max:  0.4072131592320322
# Max_compare_value:  0.5081863805759821 at idx 146
# Image filtered_1\00000556_(3).jpg Max:  0.5081863805759821
# Max_compare_value:  0.2832700204143734 at idx 83
# Image filtered_1\00000560_(4).jpg Max:  0.2832700204143734
# Max_compare_value:  0.4205289799467516 at idx 144
# Image filtered_1\00000561_(4).jpg Max:  0.4205289799467516
# Max_compare_value:  0.5605067339335819 at idx 178
# Image filtered_1\00000562_(5).jpg Max:  0.5605067339335819
# Max_compare_value:  0.53782147404927 at idx 127
# Image filtered_1\00000566_(5).jpg Max:  0.53782147404927
# Max_compare_value:  0.30336698201395923 at idx 10
# Image filtered_1\00000567_(5).jpg Max:  0.30336698201395923
# Max_compare_value:  0.27266973982088877 at idx 100
# Image filtered_1\00000569_(3).jpg Max:  0.27266973982088877
# Max_compare_value:  1.0 at idx 168
# Image filtered_1\00000569_(4).jpg Max:  1.0
# Max_compare_value:  0.4478486797240994 at idx 139
# Image filtered_1\00000571_(2).jpg Max:  0.4478486797240994
# Max_compare_value:  0.44152785807840855 at idx 162
# Image filtered_1\00000578_(3).jpg Max:  0.44152785807840855
# Max_compare_value:  0.22492242763106426 at idx 38
# Image filtered_1\00000583_(3).jpg Max:  0.22492242763106426
# Max_compare_value:  0.527327492257396 at idx 125
# Image filtered_1\00000587_(4).jpg Max:  0.527327492257396
# Max_compare_value:  0.327616618784861 at idx 54
# Image filtered_1\00000592_(3).jpg Max:  0.327616618784861
# Max_compare_value:  0.4090940652910191 at idx 31
# Image filtered_1\00000593_(2).jpg Max:  0.4090940652910191
# Max_compare_value:  0.4413069064161963 at idx 77
# Image filtered_1\00000606_(3).jpg Max:  0.4413069064161963
# Max_compare_value:  0.1656354464538181 at idx 64
# Image filtered_1\00000610_(2).jpg Max:  0.1656354464538181
# Max_compare_value:  0.3860835167030343 at idx 20
# Image filtered_1\00000613_(2).jpg Max:  0.3860835167030343
# Max_compare_value:  0.3966091817855282 at idx 197
# Image filtered_1\00000616_(2).jpg Max:  0.3966091817855282
# Max_compare_value:  0.21879242496704557 at idx 17
# Image filtered_1\00000628.jpg Max:  0.21879242496704557
# Max_compare_value:  0.41402842381536714 at idx 141
# Image filtered_1\00000634_(3).jpg Max:  0.41402842381536714
# Max_compare_value:  0.15656214105162639 at idx 153
# Image filtered_1\00000648_(2).jpg Max:  0.15656214105162639
# Max_compare_value:  0.40838675734496976 at idx 126
# Image filtered_1\00000652_(3).jpg Max:  0.40838675734496976
# Max_compare_value:  0.2203002026667941 at idx 108
# Image filtered_1\00000653_(2).jpg Max:  0.2203002026667941
# Max_compare_value:  0.23791310655277986 at idx 196
# Image filtered_1\00000653_(3).jpg Max:  0.23791310655277986
# Max_compare_value:  0.22303497411018106 at idx 11
# Image filtered_1\00000656_(3).jpg Max:  0.22303497411018106
# Max_compare_value:  0.19976007486575495 at idx 148
# Image filtered_1\00000659_(3).jpg Max:  0.19976007486575495
# Max_compare_value:  0.27379528891111415 at idx 184
# Image filtered_1\00000666.jpg Max:  0.27379528891111415
# Max_compare_value:  0.3528239365748696 at idx 1
# Image filtered_1\00000673_(3).jpg Max:  0.3528239365748696
# Max_compare_value:  0.2288794297169092 at idx 85
# Image filtered_1\00000675_(3).jpg Max:  0.2288794297169092
# Max_compare_value:  0.26148206343023644 at idx 116
# Image filtered_1\00000684_(3).jpg Max:  0.26148206343023644
# Max_compare_value:  0.2670780211951771 at idx 194
# Image filtered_1\00000695_(2).jpg Max:  0.2670780211951771
# Max_compare_value:  0.17392588473064086 at idx 101
# Image filtered_1\00000699_(3).jpg Max:  0.17392588473064086
# Max_compare_value:  0.24081146957853225 at idx 21
# Image filtered_1\00000701_(3).jpg Max:  0.24081146957853225
# Max_compare_value:  0.1810193286322904 at idx 80
# Image filtered_1\00000710.jpg Max:  0.1810193286322904
# Max_compare_value:  0.2467850048773138 at idx 47
# Image filtered_1\00000714_(2).jpg Max:  0.2467850048773138
# Max_compare_value:  0.12892646494908397 at idx 30
# Image filtered_1\00000719.jpg Max:  0.12892646494908397
# Max_compare_value:  0.17713619194678445 at idx 55
# Image filtered_1\00000719_(3).jpg Max:  0.17713619194678445
# Max_compare_value:  0.13439161848153527 at idx 9
# Image filtered_1\00000721_(3).jpg Max:  0.13439161848153527
# Max_compare_value:  0.1958230350576311 at idx 151
# Image filtered_1\00000724_(2).jpg Max:  0.1958230350576311
# Max_compare_value:  0.12206560140893156 at idx 76
# Image filtered_1\00000725.jpg Max:  0.12206560140893156
# Max_compare_value:  0.17842067695387898 at idx 174
# Image filtered_1\00000732.jpg Max:  0.17842067695387898
# Max_compare_value:  0.12354983420280928 at idx 128
# Image filtered_1\00000734_(3).jpg Max:  0.12354983420280928
# Max_compare_value:  0.13677880147686391 at idx 113
# Image filtered_1\00000742_(3).jpg Max:  0.13677880147686391
# Max_compare_value:  0.12548116586994815 at idx 53
# Image filtered_1\00000753_(2).jpg Max:  0.12548116586994815
# Max_compare_value:  0.1421339697833843 at idx 158
# Image filtered_1\00000758_(2).jpg Max:  0.1421339697833843
# Max_compare_value:  0.07913055003853452 at idx 123
# Image filtered_1\00000758_(3).jpg Max:  0.07913055003853452
# Max_compare_value:  0.10785838457183065 at idx 35
# Image filtered_1\00000765_(3).jpg Max:  0.10785838457183065
# Max_compare_value:  0.028528880400868328 at idx 155
# Image filtered_1\00000778_(3).jpg Max:  0.028528880400868328
# Max_compare_value:  0.13017421912322855 at idx 4
# Image filtered_1\00000784.jpg Max:  0.13017421912322855
# Max_compare_value:  0.010851772137464535 at idx 171
# Image filtered_1\00000787_(3).jpg Max:  0.010851772137464535
# Max_compare_value:  -0.17183145872409192 at idx 200
# Image filtered_1\00000789_(2).jpg Max:  -0.17183145872409192
